# %% [markdown]
# # <center> KIT Praktikum NN: L2-regularized Logistic Least Squares Regression </center>
#
# </br>
# On this exercise, you are going to apply what you learn from the `numpy` tutorial in the implementation of L2-regularized Logistic Least Squares Regression (LLSR). I will provide you the formula by now (you can do it yourself after the next lecture!!!), first you should use pens and papers to vectorize them. Then you implement the full of the classifier based on your vectorized version.
#
# <img src="../Images/LogisticRegression.png" style="width:298px;height:275px">
#
# </br>
# L2-regularized Logistic Least Squares Regression is similar to the standard Logistic Regression: It is a binary classifier containing only one layer, mapping the input features to only one output using sigmoid function. The differents here are two things:
# * Instead of the _binary crossentropy error_ for the loss, it uses the _squared error_.
# * It is applied the L2-regularization.
#
# Note that we will do an SGD training for this exercise. More specifically:
# * There are $m$ data instance on the training set, each has $n$ input features.
# * $x_{i}^{(j)}$ denotes the $i^{th}$ input feature of the $j^{th}$ data instance.
# * $y^{(j)}$ denotes the binary label ($0$ or $1$) of the $j^{th}$ data instance.
# * $w_{i}$ denotes the weight connecting the $i^{th}$ input feature to the output.
# * $b$ is the bias of the Logistic Least Squares Regression.
#
# So the steps of an unvectorized version are:
# * The weights are initialized using Xavier Initialization, the bias can be initialized as 0.
# * Train over 5 epochs, each epoch we do those steps:
#   *  Loop over every data instance $x^{(j)}$:
#      * Calculate the output of the LLSR: $o^{(j)} = \sigma(\sum_{i=1}^{n} w_ix_i^{(j)} + b)$
#      * Calculate the cost: squared error $c^{(j)} = (y^{(j)} - o^{(j)})^2$
#      * The final loss function is L2-regularized: $l^{(j)} = \frac{1}{2}c^{(j)} + \frac{\lambda}{2}\sum_{i=1}^{n}w_i^2$.
#      * Update the weights:
#          * Loop over every weight $w_i$ and update once at a time: $w_i = w_i - \eta((o^{(j)}-y^{(j)})o^{(j)}(1-o^{(j)})x_i^{(j)} + \lambda w_i)$
#      * Update the bias: $b = b - \eta (o^{(j)}-y^{(j)})o^{(j)}(1-o^{(j)})$
#   *  Calculate the total loss (of the epoch): $L = \frac{1}{m}\sum_{j=1}^{m}l^{(j)}$. Print it out.

# %% [markdown]
# The guideline is to avoid explicit for-loops. _Hint_: We cannot make the epoch loop disappears, but all other loops can be replaced by vectorization.

# %% [markdown]
# First, let's import numpy and math:

# %%
import numpy as np
import math

# %% [markdown]
# We will use LLSR for the MNIST_SEVEN task: predict a $128\times 128$-pixel image of a handwritten digit whether it is a "7" or not. This is a binary classification task. I did the data reading for you. There is 5000 images, I split the first 4000 images for training, 500 images for tuning, 500 images for test. On this exercise we do not need to tune anything, so we'd leave the tuning (called the _dev set_) untouch. The first field is the label ("0"-"9") of the image, the rest are the grayscale value of each pixel.

# %%
data_path = "../Data/mnist_seven.csv"
data = np.genfromtxt(data_path, delimiter=",", dtype="uint8")
train, dev, test = data[:4000], data[4000:4500], data[4500:]

# %%
def normalize(dataset):
    X = dataset[:, 1:] / 255.     # Normalize input features
    Y = (dataset[:, 0] == 7) * 1  # Convert labels from 0-9 to Is7 (1) or IsNot7(0)
    return X.T,Y.reshape(1, -1)

# %%
X_train, Y_train = normalize(train)
print(X_train.shape)
print(Y_train.shape)

X_test, Y_test = normalize(test)
print(X_test.shape)
print(Y_test.shape)

# shuffle the training data since we do SGD
# we shuffle outside the training 
# since we want to compare unvectorized and vectorized versions
# It doesn't affect to batch training later
np.random.seed(8888)     # Do not change those seedings to make our results comparable
np.random.shuffle(train)
# Out:
# (784, 4000)
# (1, 4000)
# (784, 500)
# (1, 500)

# %% [markdown]
# # Unvectorized Version of SGD
#
# First the unvectorized version of training:

# %%
def train_unvectorized(X_train, Y_train, lr=0.2, lambdar=0.0001, epochs=5):
    
    n = X_train.shape[0]
    m = X_train.shape[1]
    
    # Xavier Initialization
    np.random.seed(1234)
    w = np.random.randn(n) * (np.sqrt(2. / (n + 1)))
    b = 0

    for epoch in range(epochs):
        L = 0
        for j in range(m):   # Loop over every training instance
            # Forward pass
            z = 0 
            r = 0 # calculate the regularizer
            for i in range(n):
                z += w[i] * X_train[i,j]
                r += w[i]**2
            z += b
            o = 1. / (1 + math.exp(-z))

            # Calculate the loss
            c = (Y_train[:,j] - o)**2
            l = c / 2 + (lambdar / 2) * r
            L += l

            # Backward pass and update the weights/bias
            for i in range(n):
                w[i] -= lr * (o - Y_train[:,j]) * o * (1 - o) * X_train[i,j] + lambdar * w[i]
            b -= lr * (o - Y_train[:,j]) * o * (1 - o)
        L /= m
        print("Error of the epoch {0}: {1}".format(epoch + 1, L))
    
    return w, b

# %% [markdown]
# And the (unvectorized) inference:

# %%
def test_unvectorized(X_test, Y_test, w, b):
    
    n_test = X_test.shape[0]
    m_test = X_test.shape[1]
    corrects = 0
    
    for j in range(m_test):

        # Forward pass
        z = 0 
        for i in range(n_test):
            z += w[i] * X_test[i,j]
        z += b
        o = 1. / (1 + np.exp(-z))
        # Evaluate the outputs
        if ((o >= 0.5) and (Y_test[0, j] == 1)) \
        or ((o < 0.5) and (Y_test[0, j] == 0)):
            corrects +=1
    
    print("Accuracy of our LLSR:" + str((corrects * 100.) / m_test) + "%")
    
    return corrects

# %% [markdown]
# Test on our test data. The accuracy should be better than 89.2%. This high score 89.2% is the baseline, achieved by do nothing rather than predicting all images are not a "seven" :p.

# %%
w, b = train_unvectorized(X_train, Y_train)
_ = test_unvectorized(X_test, Y_test, w, b)
# Out:
# Error of the epoch 1: [ 0.01169449]
# Error of the epoch 2: [ 0.00879146]
# Error of the epoch 3: [ 0.00833166]
# Error of the epoch 4: [ 0.00814921]
# Error of the epoch 5: [ 0.00805634]
# Accuracy of our LLSR:98.0%

# %% [markdown]
# # Vectorized Version of Stochastic Gradient Descent
#
# Now we move to the vectorized version of training and inference, just replace for-loops and total-sums by $np.dot()$,  $np.sum()$ and the numpy pair-wise operations (you should do the vectorization using pens and papers first).

# %%
def train_vectorized(X_train, Y_train, lr=0.2, lambdar=0.0001, epochs=5):
    
    n = X_train.shape[0]
    m = X_train.shape[1]
    
    # Xavier Initialization
    np.random.seed(1234)
    w = np.random.randn(n) * (np.sqrt(2. / (n + 1)))
    b = 0

    for epoch in range(epochs):
        L = 0
        for j in range(m):

            # Forward pass
            z = np.dot(w, X_train[:,j]) + b
            r = np.sum(w**2)
            o = 1. / (1 + np.exp(-z))

            # Calculate the loss (for each instance - SGD) 
            c = (Y_train[:,j] - o)**2
            l = c / 2 + (lambdar / 2) * r
            L += l

            # Backward pass and update the weights/bias (for each instance - SGD) 
            w -= lr * (o - Y_train[:,j]) * o * (1 - o) * X_train[:,j] + lambdar * w 
            b -= lr * (o - Y_train[:,j]) * o * (1 - o)
        L /= m
        print("Error of the epoch {0}: {1}".format(epoch + 1, L))
    return w, b

# %% [markdown]
# And the vectorized inference (short, clear and fast):

# %%
def test_vectorized(X_test, Y_test, w, b):
    
    m_test = X_test.shape[1]
    result = np.zeros((1, m_test))
    
    z = np.dot(w, X_test) + b
    o = 1. / (1 + np.exp(-z))
    result = (o > 0.5)
    corrects = np.sum(result == Y_test)

    print("Accuracy of our LLSR:" + str((corrects * 100.) / m_test) + "%")
    
    return corrects

# %% [markdown]
# Those following runs should return exact the same outputs like the (unvectorized) training and inference before but in less than a second. The vectorization should be more effective (much faster) if this is not an one-layer logistic regression but a deep network.

# %%
w, b = train_vectorized(X_train, Y_train)
_ = test_vectorized(X_test, Y_test, w, b)
# Out:
# Error of the epoch 1: [ 0.01169449]
# Error of the epoch 2: [ 0.00879146]
# Error of the epoch 3: [ 0.00833166]
# Error of the epoch 4: [ 0.00814921]
# Error of the epoch 5: [ 0.00805634]
# Accuracy of our LLSR:98.0%

# %% [markdown]
# # Vectorized Version of Batch Gradient Descent
#
# Here is the fully vectorized version, batch training (vectorizing over training instances). The formula (you might be able to derive them after the next lecture):
#
# $$ z = w \cdot X + b $$
#
# $$ o = \sigma(z) $$
#
# $$ C = \frac{1}{2m}\sum_{j=1}^{m}(y^{(j)}-o^{(j)})^2 $$
#
# $$ R = \frac{1}{2m}\sum_{i=1}^{n}w_i^2 $$
#
# $$ L = C + \lambda R $$
#
# $$ \frac{\partial C}{\partial z^{(j)}} = \frac{1}{m}(o^{(j)} - Y^{(j)}) * o^{(j)} * (1 - o^{(j)}) $$
#
# $$ \frac{\partial z^{(j)}}{\partial w_i} = x_i $$
#
# $$ \Rightarrow \frac{\partial C}{\partial w} = \frac{\partial C}{\partial z} \cdot X^T $$
#
# $$ \frac{\partial R}{\partial w} = \frac{1}{m}w $$
#
# $$ \Rightarrow \frac{\partial L}{\partial w} = \frac{\partial C}{\partial w} + \lambda\frac{\partial R}{\partial w} $$
#
# $$ \frac{\partial z}{\partial b} = 1 $$
#
# $$ \Rightarrow \frac{\partial L}{\partial b} = \frac{\partial C}{\partial b} = \sum_{j=1}^{m}(o^{(j)} - Y^{(j)}) * o^{(j)} * (1 - o^{(j)}) $$
#
# $$ w = w - \eta * \frac{\partial L}{\partial w} $$
#
# $$ b = b - \eta *  \frac{\partial L}{\partial b} $$

# %%
def train_batch(X_train, Y_train, lr=0.1, lambdar=0.0001, epochs=50):
    
    n = X_train.shape[0]
    m = X_train.shape[1]

    # Xavier Initialization
    np.random.seed(1234)
    w = np.random.randn(1, n) * (np.sqrt(2. / (n + 1)))
    b = 0

    for epoch in range(epochs):

        # Forward pass
        z = np.dot(w, X_train) + b
        o = 1. / (1 + np.exp(-z))
        r = np.sum(w**2)    

        # Calculate the loss 
        # (axis here makes the training more general \
        # if there are more output neurons than 1, \
        # we want to sum over the instances, so axis=1)
        L = (np.sum((Y_train - o)**2, axis=1) + lambdar * r) / (2 * m)

        # Backward pass and update the weights/bias
        w -= lr * (np.dot((o - Y_train) * o * (1 - o), X_train.T) + lambdar * w) / m
        b -= lr * (np.sum((o - Y_train) * o * (1 - o))) / m

        print("Error of the epoch {0}: {1}".format(epoch + 1, L))
        
    return w, b

# %% [markdown]
# Since it is a batch training and requires different hyperparameters, the result might not be comparable to the SGD trainings above.

# %%
w_batch, b_batch = train_batch(X_train, Y_train, lr=2, lambdar=0.5, epochs=1000)
_ = test_vectorized(X_test, Y_test, w_batch, b_batch)
# Out:
# Error of the epoch 1: [ 0.16787075]
# Error of the epoch 2: [ 0.05099794]
# Error of the epoch 3: [ 0.0509903]
# Error of the epoch 4: [ 0.05098236]
# Error of the epoch 5: [ 0.05097411]
# Error of the epoch 6: [ 0.05096553]
# Error of the epoch 7: [ 0.0509566]
# Error of the epoch 8: [ 0.05094729]
# Error of the epoch 9: [ 0.05093758]
# Error of the epoch 10: [ 0.05092744]
# Error of the epoch 11: [ 0.05091684]
# Error of the epoch 12: [ 0.05090575]
# Error of the epoch 13: [ 0.05089413]
# Error of the epoch 14: [ 0.05088193]
# Error of the epoch 15: [ 0.05086912]
# Error of the epoch 16: [ 0.05085564]
# Error of the epoch 17: [ 0.05084144]
# Error of the epoch 18: [ 0.05082646]
# Error of the epoch 19: [ 0.05081062]
# Error of the epoch 20: [ 0.05079386]
# Error of the epoch 21: [ 0.05077608]
# Error of the epoch 22: [ 0.05075718]
# Error of the epoch 23: [ 0.05073706]
# Error of the epoch 24: [ 0.05071559]
# Error of the epoch 25: [ 0.05069262]
# Error of the epoch 26: [ 0.05066798]
# Error of the epoch 27: [ 0.05064149]
# Error of the epoch 28: [ 0.05061293]
# Error of the epoch 29: [ 0.05058202]
# Error of the epoch 30: [ 0.05054848]
# Error of the epoch 31: [ 0.05051193]
# Error of the epoch 32: [ 0.05047195]
# Error of the epoch 33: [ 0.05042804]
# Error of the epoch 34: [ 0.05037956]
# Error of the epoch 35: [ 0.05032577]
# Error of the epoch 36: [ 0.05026573]
# Error of the epoch 37: [ 0.05019829]
# Error of the epoch 38: [ 0.05012198]
# Error of the epoch 39: [ 0.05003495]
# Error of the epoch 40: [ 0.04993476]
# Error of the epoch 41: [ 0.04981823]
# Error of the epoch 42: [ 0.04968105]
# Error of the epoch 43: [ 0.04951733]
# Error of the epoch 44: [ 0.04931873]
# Error of the epoch 45: [ 0.04907318]
# Error of the epoch 46: [ 0.04876257]
# Error of the epoch 47: [ 0.04835864]
# Error of the epoch 48: [ 0.04781528]
# Error of the epoch 49: [ 0.04705315]
# Error of the epoch 50: [ 0.04592744]
# Error of the epoch 51: [ 0.0441577]
# Error of the epoch 52: [ 0.04118232]
# Error of the epoch 53: [ 0.03598122]
# Error of the epoch 54: [ 0.02780978]
# Error of the epoch 55: [ 0.01991051]
# Error of the epoch 56: [ 0.01674715]
# Error of the epoch 57: [ 0.01597657]
# Error of the epoch 58: [ 0.01556372]
# Error of the epoch 59: [ 0.01520955]
# Error of the epoch 60: [ 0.01489118]
# Error of the epoch 61: [ 0.01460264]
# Error of the epoch 62: [ 0.01433963]
# Error of the epoch 63: [ 0.01409866]
# Error of the epoch 64: [ 0.01387683]
# Error of the epoch 65: [ 0.01367176]
# Error of the epoch 66: [ 0.01348144]
# Error of the epoch 67: [ 0.01330416]
# Error of the epoch 68: [ 0.0131385]
# Error of the epoch 69: [ 0.01298323]
# Error of the epoch 70: [ 0.01283728]
# Error of the epoch 71: [ 0.01269976]
# Error of the epoch 72: [ 0.01256986]
# Error of the epoch 73: [ 0.01244689]
# Error of the epoch 74: [ 0.01233025]
# Error of the epoch 75: [ 0.0122194]
# Error of the epoch 76: [ 0.01211387]
# Error of the epoch 77: [ 0.01201323]
# Error of the epoch 78: [ 0.0119171]
# Error of the epoch 79: [ 0.01182516]
# Error of the epoch 80: [ 0.0117371]
# Error of the epoch 81: [ 0.01165265]
# Error of the epoch 82: [ 0.01157156]
# Error of the epoch 83: [ 0.01149361]
# Error of the epoch 84: [ 0.01141859]
# Error of the epoch 85: [ 0.01134633]
# Error of the epoch 86: [ 0.01127664]
# Error of the epoch 87: [ 0.01120939]
# Error of the epoch 88: [ 0.01114443]
# Error of the epoch 89: [ 0.01108162]
# Error of the epoch 90: [ 0.01102085]
# Error of the epoch 91: [ 0.01096201]
# Error of the epoch 92: [ 0.01090499]
# Error of the epoch 93: [ 0.0108497]
# Error of the epoch 94: [ 0.01079605]
# Error of the epoch 95: [ 0.01074396]
# Error of the epoch 96: [ 0.01069335]
# Error of the epoch 97: [ 0.01064416]
# Error of the epoch 98: [ 0.01059632]
# Error of the epoch 99: [ 0.01054976]
# Error of the epoch 100: [ 0.01050442]
# Error of the epoch 101: [ 0.01046026]
# Error of the epoch 102: [ 0.01041722]
# Error of the epoch 103: [ 0.01037525]
# Error of the epoch 104: [ 0.01033432]
# Error of the epoch 105: [ 0.01029436]
# Error of the epoch 106: [ 0.01025536]
# Error of the epoch 107: [ 0.01021726]
# Error of the epoch 108: [ 0.01018004]
# Error of the epoch 109: [ 0.01014365]
# Error of the epoch 110: [ 0.01010807]
# Error of the epoch 111: [ 0.01007327]
# Error of the epoch 112: [ 0.01003922]
# Error of the epoch 113: [ 0.01000589]
# Error of the epoch 114: [ 0.00997325]
# Error of the epoch 115: [ 0.00994128]
# Error of the epoch 116: [ 0.00990997]
# Error of the epoch 117: [ 0.00987927]
# Error of the epoch 118: [ 0.00984919]
# Error of the epoch 119: [ 0.00981968]
# Error of the epoch 120: [ 0.00979074]
# Error of the epoch 121: [ 0.00976235]
# Error of the epoch 122: [ 0.00973449]
# Error of the epoch 123: [ 0.00970714]
# Error of the epoch 124: [ 0.00968028]
# Error of the epoch 125: [ 0.00965391]
# Error of the epoch 126: [ 0.00962801]
# Error of the epoch 127: [ 0.00960255]
# Error of the epoch 128: [ 0.00957754]
# Error of the epoch 129: [ 0.00955295]
# Error of the epoch 130: [ 0.00952878]
# Error of the epoch 131: [ 0.00950501]
# Error of the epoch 132: [ 0.00948163]
# Error of the epoch 133: [ 0.00945863]
# Error of the epoch 134: [ 0.009436]
# Error of the epoch 135: [ 0.00941372]
# Error of the epoch 136: [ 0.0093918]
# Error of the epoch 137: [ 0.00937022]
# Error of the epoch 138: [ 0.00934897]
# Error of the epoch 139: [ 0.00932804]
# Error of the epoch 140: [ 0.00930743]
# Error of the epoch 141: [ 0.00928712]
# Error of the epoch 142: [ 0.00926711]
# Error of the epoch 143: [ 0.00924739]
# Error of the epoch 144: [ 0.00922796]
# Error of the epoch 145: [ 0.0092088]
# Error of the epoch 146: [ 0.00918991]
# Error of the epoch 147: [ 0.00917128]
# Error of the epoch 148: [ 0.00915292]
# Error of the epoch 149: [ 0.0091348]
# Error of the epoch 150: [ 0.00911693]
# Error of the epoch 151: [ 0.00909929]
# Error of the epoch 152: [ 0.00908189]
# Error of the epoch 153: [ 0.00906472]
# Error of the epoch 154: [ 0.00904778]
# Error of the epoch 155: [ 0.00903105]
# Error of the epoch 156: [ 0.00901453]
# Error of the epoch 157: [ 0.00899823]
# Error of the epoch 158: [ 0.00898212]
# Error of the epoch 159: [ 0.00896622]
# Error of the epoch 160: [ 0.00895051]
# Error of the epoch 161: [ 0.008935]
# Error of the epoch 162: [ 0.00891967]
# Error of the epoch 163: [ 0.00890452]
# Error of the epoch 164: [ 0.00888956]
# Error of the epoch 165: [ 0.00887477]
# Error of the epoch 166: [ 0.00886015]
# Error of the epoch 167: [ 0.0088457]
# Error of the epoch 168: [ 0.00883142]
# Error of the epoch 169: [ 0.0088173]
# Error of the epoch 170: [ 0.00880334]
# Error of the epoch 171: [ 0.00878953]
# Error of the epoch 172: [ 0.00877588]
# Error of the epoch 173: [ 0.00876237]
# Error of the epoch 174: [ 0.00874901]
# Error of the epoch 175: [ 0.0087358]
# Error of the epoch 176: [ 0.00872273]
# Error of the epoch 177: [ 0.0087098]
# Error of the epoch 178: [ 0.008697]
# Error of the epoch 179: [ 0.00868433]
# Error of the epoch 180: [ 0.0086718]
# Error of the epoch 181: [ 0.0086594]
# Error of the epoch 182: [ 0.00864712]
# Error of the epoch 183: [ 0.00863497]
# Error of the epoch 184: [ 0.00862293]
# Error of the epoch 185: [ 0.00861102]
# Error of the epoch 186: [ 0.00859923]
# Error of the epoch 187: [ 0.00858755]
# Error of the epoch 188: [ 0.00857598]
# Error of the epoch 189: [ 0.00856453]
# Error of the epoch 190: [ 0.00855319]
# Error of the epoch 191: [ 0.00854195]
# Error of the epoch 192: [ 0.00853082]
# Error of the epoch 193: [ 0.00851979]
# Error of the epoch 194: [ 0.00850887]
# Error of the epoch 195: [ 0.00849804]
# Error of the epoch 196: [ 0.00848732]
# Error of the epoch 197: [ 0.00847669]
# Error of the epoch 198: [ 0.00846616]
# Error of the epoch 199: [ 0.00845572]
# Error of the epoch 200: [ 0.00844538]
# Error of the epoch 201: [ 0.00843512]
# Error of the epoch 202: [ 0.00842496]
# Error of the epoch 203: [ 0.00841489]
# Error of the epoch 204: [ 0.0084049]
# Error of the epoch 205: [ 0.00839499]
# Error of the epoch 206: [ 0.00838518]
# Error of the epoch 207: [ 0.00837544]
# Error of the epoch 208: [ 0.00836579]
# Error of the epoch 209: [ 0.00835621]
# Error of the epoch 210: [ 0.00834672]
# Error of the epoch 211: [ 0.0083373]
# Error of the epoch 212: [ 0.00832796]
# Error of the epoch 213: [ 0.0083187]
# Error of the epoch 214: [ 0.00830951]
# Error of the epoch 215: [ 0.00830039]
# Error of the epoch 216: [ 0.00829135]
# Error of the epoch 217: [ 0.00828237]
# Error of the epoch 218: [ 0.00827347]
# Error of the epoch 219: [ 0.00826464]
# Error of the epoch 220: [ 0.00825587]
# Error of the epoch 221: [ 0.00824717]
# Error of the epoch 222: [ 0.00823854]
# Error of the epoch 223: [ 0.00822998]
# Error of the epoch 224: [ 0.00822147]
# Error of the epoch 225: [ 0.00821304]
# Error of the epoch 226: [ 0.00820466]
# Error of the epoch 227: [ 0.00819635]
# Error of the epoch 228: [ 0.00818809]
# Error of the epoch 229: [ 0.0081799]
# Error of the epoch 230: [ 0.00817177]
# Error of the epoch 231: [ 0.00816369]
# Error of the epoch 232: [ 0.00815567]
# Error of the epoch 233: [ 0.00814771]
# Error of the epoch 234: [ 0.0081398]
# Error of the epoch 235: [ 0.00813196]
# Error of the epoch 236: [ 0.00812416]
# Error of the epoch 237: [ 0.00811642]
# Error of the epoch 238: [ 0.00810873]
# Error of the epoch 239: [ 0.00810109]
# Error of the epoch 240: [ 0.00809351]
# Error of the epoch 241: [ 0.00808598]
# Error of the epoch 242: [ 0.0080785]
# Error of the epoch 243: [ 0.00807106]
# Error of the epoch 244: [ 0.00806368]
# Error of the epoch 245: [ 0.00805634]
# Error of the epoch 246: [ 0.00804906]
# Error of the epoch 247: [ 0.00804182]
# Error of the epoch 248: [ 0.00803462]
# Error of the epoch 249: [ 0.00802748]
# Error of the epoch 250: [ 0.00802038]
# Error of the epoch 251: [ 0.00801332]
# Error of the epoch 252: [ 0.00800631]
# Error of the epoch 253: [ 0.00799934]
# Error of the epoch 254: [ 0.00799241]
# Error of the epoch 255: [ 0.00798553]
# Error of the epoch 256: [ 0.00797869]
# Error of the epoch 257: [ 0.00797189]
# Error of the epoch 258: [ 0.00796514]
# Error of the epoch 259: [ 0.00795842]
# Error of the epoch 260: [ 0.00795175]
# Error of the epoch 261: [ 0.00794511]
# Error of the epoch 262: [ 0.00793852]
# Error of the epoch 263: [ 0.00793196]
# Error of the epoch 264: [ 0.00792544]
# Error of the epoch 265: [ 0.00791896]
# Error of the epoch 266: [ 0.00791252]
# Error of the epoch 267: [ 0.00790611]
# Error of the epoch 268: [ 0.00789974]
# Error of the epoch 269: [ 0.00789341]
# Error of the epoch 270: [ 0.00788711]
# Error of the epoch 271: [ 0.00788085]
# Error of the epoch 272: [ 0.00787462]
# Error of the epoch 273: [ 0.00786843]
# Error of the epoch 274: [ 0.00786227]
# Error of the epoch 275: [ 0.00785615]
# Error of the epoch 276: [ 0.00785006]
# Error of the epoch 277: [ 0.007844]
# Error of the epoch 278: [ 0.00783798]
# Error of the epoch 279: [ 0.00783198]
# Error of the epoch 280: [ 0.00782602]
# Error of the epoch 281: [ 0.0078201]
# Error of the epoch 282: [ 0.0078142]
# Error of the epoch 283: [ 0.00780833]
# Error of the epoch 284: [ 0.0078025]
# Error of the epoch 285: [ 0.00779669]
# Error of the epoch 286: [ 0.00779092]
# Error of the epoch 287: [ 0.00778517]
# Error of the epoch 288: [ 0.00777946]
# Error of the epoch 289: [ 0.00777377]
# Error of the epoch 290: [ 0.00776812]
# Error of the epoch 291: [ 0.00776249]
# Error of the epoch 292: [ 0.00775689]
# Error of the epoch 293: [ 0.00775131]
# Error of the epoch 294: [ 0.00774577]
# Error of the epoch 295: [ 0.00774025]
# Error of the epoch 296: [ 0.00773476]
# Error of the epoch 297: [ 0.0077293]
# Error of the epoch 298: [ 0.00772386]
# Error of the epoch 299: [ 0.00771845]
# Error of the epoch 300: [ 0.00771306]
# Error of the epoch 301: [ 0.0077077]
# Error of the epoch 302: [ 0.00770237]
# Error of the epoch 303: [ 0.00769706]
# Error of the epoch 304: [ 0.00769178]
# Error of the epoch 305: [ 0.00768652]
# Error of the epoch 306: [ 0.00768129]
# Error of the epoch 307: [ 0.00767608]
# Error of the epoch 308: [ 0.00767089]
# Error of the epoch 309: [ 0.00766573]
# Error of the epoch 310: [ 0.00766059]
# Error of the epoch 311: [ 0.00765548]
# Error of the epoch 312: [ 0.00765038]
# Error of the epoch 313: [ 0.00764532]
# Error of the epoch 314: [ 0.00764027]
# Error of the epoch 315: [ 0.00763525]
# Error of the epoch 316: [ 0.00763024]
# Error of the epoch 317: [ 0.00762527]
# Error of the epoch 318: [ 0.00762031]
# Error of the epoch 319: [ 0.00761537]
# Error of the epoch 320: [ 0.00761046]
# Error of the epoch 321: [ 0.00760556]
# Error of the epoch 322: [ 0.00760069]
# Error of the epoch 323: [ 0.00759584]
# Error of the epoch 324: [ 0.00759101]
# Error of the epoch 325: [ 0.0075862]
# Error of the epoch 326: [ 0.00758141]
# Error of the epoch 327: [ 0.00757664]
# Error of the epoch 328: [ 0.00757189]
# Error of the epoch 329: [ 0.00756716]
# Error of the epoch 330: [ 0.00756245]
# Error of the epoch 331: [ 0.00755776]
# Error of the epoch 332: [ 0.00755309]
# Error of the epoch 333: [ 0.00754844]
# Error of the epoch 334: [ 0.00754381]
# Error of the epoch 335: [ 0.00753919]
# Error of the epoch 336: [ 0.00753459]
# Error of the epoch 337: [ 0.00753002]
# Error of the epoch 338: [ 0.00752546]
# Error of the epoch 339: [ 0.00752092]
# Error of the epoch 340: [ 0.00751639]
# Error of the epoch 341: [ 0.00751189]
# Error of the epoch 342: [ 0.0075074]
# Error of the epoch 343: [ 0.00750293]
# Error of the epoch 344: [ 0.00749848]
# Error of the epoch 345: [ 0.00749404]
# Error of the epoch 346: [ 0.00748963]
# Error of the epoch 347: [ 0.00748522]
# Error of the epoch 348: [ 0.00748084]
# Error of the epoch 349: [ 0.00747647]
# Error of the epoch 350: [ 0.00747212]
# Error of the epoch 351: [ 0.00746779]
# Error of the epoch 352: [ 0.00746347]
# Error of the epoch 353: [ 0.00745917]
# Error of the epoch 354: [ 0.00745488]
# Error of the epoch 355: [ 0.00745061]
# Error of the epoch 356: [ 0.00744636]
# Error of the epoch 357: [ 0.00744212]
# Error of the epoch 358: [ 0.0074379]
# Error of the epoch 359: [ 0.00743369]
# Error of the epoch 360: [ 0.0074295]
# Error of the epoch 361: [ 0.00742532]
# Error of the epoch 362: [ 0.00742116]
# Error of the epoch 363: [ 0.00741701]
# Error of the epoch 364: [ 0.00741288]
# Error of the epoch 365: [ 0.00740876]
# Error of the epoch 366: [ 0.00740466]
# Error of the epoch 367: [ 0.00740057]
# Error of the epoch 368: [ 0.00739649]
# Error of the epoch 369: [ 0.00739244]
# Error of the epoch 370: [ 0.00738839]
# Error of the epoch 371: [ 0.00738436]
# Error of the epoch 372: [ 0.00738034]
# Error of the epoch 373: [ 0.00737634]
# Error of the epoch 374: [ 0.00737235]
# Error of the epoch 375: [ 0.00736837]
# Error of the epoch 376: [ 0.00736441]
# Error of the epoch 377: [ 0.00736046]
# Error of the epoch 378: [ 0.00735653]
# Error of the epoch 379: [ 0.00735261]
# Error of the epoch 380: [ 0.0073487]
# Error of the epoch 381: [ 0.0073448]
# Error of the epoch 382: [ 0.00734092]
# Error of the epoch 383: [ 0.00733705]
# Error of the epoch 384: [ 0.00733319]
# Error of the epoch 385: [ 0.00732935]
# Error of the epoch 386: [ 0.00732552]
# Error of the epoch 387: [ 0.0073217]
# Error of the epoch 388: [ 0.00731789]
# Error of the epoch 389: [ 0.0073141]
# Error of the epoch 390: [ 0.00731032]
# Error of the epoch 391: [ 0.00730655]
# Error of the epoch 392: [ 0.00730279]
# Error of the epoch 393: [ 0.00729905]
# Error of the epoch 394: [ 0.00729532]
# Error of the epoch 395: [ 0.0072916]
# Error of the epoch 396: [ 0.00728789]
# Error of the epoch 397: [ 0.00728419]
# Error of the epoch 398: [ 0.00728051]
# Error of the epoch 399: [ 0.00727683]
# Error of the epoch 400: [ 0.00727317]
# Error of the epoch 401: [ 0.00726952]
# Error of the epoch 402: [ 0.00726588]
# Error of the epoch 403: [ 0.00726225]
# Error of the epoch 404: [ 0.00725864]
# Error of the epoch 405: [ 0.00725503]
# Error of the epoch 406: [ 0.00725144]
# Error of the epoch 407: [ 0.00724786]
# Error of the epoch 408: [ 0.00724428]
# Error of the epoch 409: [ 0.00724072]
# Error of the epoch 410: [ 0.00723717]
# Error of the epoch 411: [ 0.00723364]
# Error of the epoch 412: [ 0.00723011]
# Error of the epoch 413: [ 0.00722659]
# Error of the epoch 414: [ 0.00722308]
# Error of the epoch 415: [ 0.00721959]
# Error of the epoch 416: [ 0.0072161]
# Error of the epoch 417: [ 0.00721263]
# Error of the epoch 418: [ 0.00720916]
# Error of the epoch 419: [ 0.00720571]
# Error of the epoch 420: [ 0.00720226]
# Error of the epoch 421: [ 0.00719883]
# Error of the epoch 422: [ 0.00719541]
# Error of the epoch 423: [ 0.00719199]
# Error of the epoch 424: [ 0.00718859]
# Error of the epoch 425: [ 0.0071852]
# Error of the epoch 426: [ 0.00718181]
# Error of the epoch 427: [ 0.00717844]
# Error of the epoch 428: [ 0.00717508]
# Error of the epoch 429: [ 0.00717172]
# Error of the epoch 430: [ 0.00716838]
# Error of the epoch 431: [ 0.00716504]
# Error of the epoch 432: [ 0.00716172]
# Error of the epoch 433: [ 0.0071584]
# Error of the epoch 434: [ 0.0071551]
# Error of the epoch 435: [ 0.0071518]
# Error of the epoch 436: [ 0.00714852]
# Error of the epoch 437: [ 0.00714524]
# Error of the epoch 438: [ 0.00714197]
# Error of the epoch 439: [ 0.00713871]
# Error of the epoch 440: [ 0.00713546]
# Error of the epoch 441: [ 0.00713222]
# Error of the epoch 442: [ 0.00712899]
# Error of the epoch 443: [ 0.00712577]
# Error of the epoch 444: [ 0.00712256]
# Error of the epoch 445: [ 0.00711936]
# Error of the epoch 446: [ 0.00711616]
# Error of the epoch 447: [ 0.00711298]
# Error of the epoch 448: [ 0.0071098]
# Error of the epoch 449: [ 0.00710663]
# Error of the epoch 450: [ 0.00710347]
# Error of the epoch 451: [ 0.00710032]
# Error of the epoch 452: [ 0.00709718]
# Error of the epoch 453: [ 0.00709405]
# Error of the epoch 454: [ 0.00709093]
# Error of the epoch 455: [ 0.00708781]
# Error of the epoch 456: [ 0.0070847]
# Error of the epoch 457: [ 0.00708161]
# Error of the epoch 458: [ 0.00707852]
# Error of the epoch 459: [ 0.00707543]
# Error of the epoch 460: [ 0.00707236]
# Error of the epoch 461: [ 0.0070693]
# Error of the epoch 462: [ 0.00706624]
# Error of the epoch 463: [ 0.00706319]
# Error of the epoch 464: [ 0.00706015]
# Error of the epoch 465: [ 0.00705712]
# Error of the epoch 466: [ 0.0070541]
# Error of the epoch 467: [ 0.00705109]
# Error of the epoch 468: [ 0.00704808]
# Error of the epoch 469: [ 0.00704508]
# Error of the epoch 470: [ 0.00704209]
# Error of the epoch 471: [ 0.00703911]
# Error of the epoch 472: [ 0.00703613]
# Error of the epoch 473: [ 0.00703317]
# Error of the epoch 474: [ 0.00703021]
# Error of the epoch 475: [ 0.00702726]
# Error of the epoch 476: [ 0.00702432]
# Error of the epoch 477: [ 0.00702138]
# Error of the epoch 478: [ 0.00701845]
# Error of the epoch 479: [ 0.00701554]
# Error of the epoch 480: [ 0.00701262]
# Error of the epoch 481: [ 0.00700972]
# Error of the epoch 482: [ 0.00700682]
# Error of the epoch 483: [ 0.00700394]
# Error of the epoch 484: [ 0.00700106]
# Error of the epoch 485: [ 0.00699818]
# Error of the epoch 486: [ 0.00699532]
# Error of the epoch 487: [ 0.00699246]
# Error of the epoch 488: [ 0.00698961]
# Error of the epoch 489: [ 0.00698677]
# Error of the epoch 490: [ 0.00698393]
# Error of the epoch 491: [ 0.0069811]
# Error of the epoch 492: [ 0.00697828]
# Error of the epoch 493: [ 0.00697547]
# Error of the epoch 494: [ 0.00697266]
# Error of the epoch 495: [ 0.00696986]
# Error of the epoch 496: [ 0.00696707]
# Error of the epoch 497: [ 0.00696429]
# Error of the epoch 498: [ 0.00696151]
# Error of the epoch 499: [ 0.00695874]
# Error of the epoch 500: [ 0.00695598]
# Error of the epoch 501: [ 0.00695323]
# Error of the epoch 502: [ 0.00695048]
# Error of the epoch 503: [ 0.00694774]
# Error of the epoch 504: [ 0.006945]
# Error of the epoch 505: [ 0.00694228]
# Error of the epoch 506: [ 0.00693956]
# Error of the epoch 507: [ 0.00693685]
# Error of the epoch 508: [ 0.00693414]
# Error of the epoch 509: [ 0.00693144]
# Error of the epoch 510: [ 0.00692875]
# Error of the epoch 511: [ 0.00692606]
# Error of the epoch 512: [ 0.00692339]
# Error of the epoch 513: [ 0.00692072]
# Error of the epoch 514: [ 0.00691805]
# Error of the epoch 515: [ 0.00691539]
# Error of the epoch 516: [ 0.00691274]
# Error of the epoch 517: [ 0.0069101]
# Error of the epoch 518: [ 0.00690746]
# Error of the epoch 519: [ 0.00690483]
# Error of the epoch 520: [ 0.00690221]
# Error of the epoch 521: [ 0.00689959]
# Error of the epoch 522: [ 0.00689698]
# Error of the epoch 523: [ 0.00689438]
# Error of the epoch 524: [ 0.00689178]
# Error of the epoch 525: [ 0.00688919]
# Error of the epoch 526: [ 0.00688661]
# Error of the epoch 527: [ 0.00688403]
# Error of the epoch 528: [ 0.00688146]
# Error of the epoch 529: [ 0.0068789]
# Error of the epoch 530: [ 0.00687634]
# Error of the epoch 531: [ 0.00687379]
# Error of the epoch 532: [ 0.00687124]
# Error of the epoch 533: [ 0.0068687]
# Error of the epoch 534: [ 0.00686617]
# Error of the epoch 535: [ 0.00686365]
# Error of the epoch 536: [ 0.00686113]
# Error of the epoch 537: [ 0.00685862]
# Error of the epoch 538: [ 0.00685611]
# Error of the epoch 539: [ 0.00685361]
# Error of the epoch 540: [ 0.00685112]
# Error of the epoch 541: [ 0.00684863]
# Error of the epoch 542: [ 0.00684615]
# Error of the epoch 543: [ 0.00684367]
# Error of the epoch 544: [ 0.0068412]
# Error of the epoch 545: [ 0.00683874]
# Error of the epoch 546: [ 0.00683628]
# Error of the epoch 547: [ 0.00683383]
# Error of the epoch 548: [ 0.00683139]
# Error of the epoch 549: [ 0.00682895]
# Error of the epoch 550: [ 0.00682652]
# Error of the epoch 551: [ 0.00682409]
# Error of the epoch 552: [ 0.00682167]
# Error of the epoch 553: [ 0.00681926]
# Error of the epoch 554: [ 0.00681685]
# Error of the epoch 555: [ 0.00681445]
# Error of the epoch 556: [ 0.00681206]
# Error of the epoch 557: [ 0.00680967]
# Error of the epoch 558: [ 0.00680728]
# Error of the epoch 559: [ 0.0068049]
# Error of the epoch 560: [ 0.00680253]
# Error of the epoch 561: [ 0.00680017]
# Error of the epoch 562: [ 0.00679781]
# Error of the epoch 563: [ 0.00679545]
# Error of the epoch 564: [ 0.0067931]
# Error of the epoch 565: [ 0.00679076]
# Error of the epoch 566: [ 0.00678842]
# Error of the epoch 567: [ 0.00678609]
# Error of the epoch 568: [ 0.00678377]
# Error of the epoch 569: [ 0.00678145]
# Error of the epoch 570: [ 0.00677914]
# Error of the epoch 571: [ 0.00677683]
# Error of the epoch 572: [ 0.00677453]
# Error of the epoch 573: [ 0.00677223]
# Error of the epoch 574: [ 0.00676994]
# Error of the epoch 575: [ 0.00676765]
# Error of the epoch 576: [ 0.00676537]
# Error of the epoch 577: [ 0.0067631]
# Error of the epoch 578: [ 0.00676083]
# Error of the epoch 579: [ 0.00675857]
# Error of the epoch 580: [ 0.00675631]
# Error of the epoch 581: [ 0.00675406]
# Error of the epoch 582: [ 0.00675181]
# Error of the epoch 583: [ 0.00674957]
# Error of the epoch 584: [ 0.00674734]
# Error of the epoch 585: [ 0.00674511]
# Error of the epoch 586: [ 0.00674288]
# Error of the epoch 587: [ 0.00674067]
# Error of the epoch 588: [ 0.00673845]
# Error of the epoch 589: [ 0.00673624]
# Error of the epoch 590: [ 0.00673404]
# Error of the epoch 591: [ 0.00673184]
# Error of the epoch 592: [ 0.00672965]
# Error of the epoch 593: [ 0.00672747]
# Error of the epoch 594: [ 0.00672529]
# Error of the epoch 595: [ 0.00672311]
# Error of the epoch 596: [ 0.00672094]
# Error of the epoch 597: [ 0.00671878]
# Error of the epoch 598: [ 0.00671662]
# Error of the epoch 599: [ 0.00671446]
# Error of the epoch 600: [ 0.00671231]
# Error of the epoch 601: [ 0.00671017]
# Error of the epoch 602: [ 0.00670803]
# Error of the epoch 603: [ 0.0067059]
# Error of the epoch 604: [ 0.00670377]
# Error of the epoch 605: [ 0.00670165]
# Error of the epoch 606: [ 0.00669953]
# Error of the epoch 607: [ 0.00669742]
# Error of the epoch 608: [ 0.00669531]
# Error of the epoch 609: [ 0.00669321]
# Error of the epoch 610: [ 0.00669111]
# Error of the epoch 611: [ 0.00668902]
# Error of the epoch 612: [ 0.00668693]
# Error of the epoch 613: [ 0.00668485]
# Error of the epoch 614: [ 0.00668277]
# Error of the epoch 615: [ 0.0066807]
# Error of the epoch 616: [ 0.00667863]
# Error of the epoch 617: [ 0.00667657]
# Error of the epoch 618: [ 0.00667451]
# Error of the epoch 619: [ 0.00667246]
# Error of the epoch 620: [ 0.00667041]
# Error of the epoch 621: [ 0.00666837]
# Error of the epoch 622: [ 0.00666633]
# Error of the epoch 623: [ 0.0066643]
# Error of the epoch 624: [ 0.00666227]
# Error of the epoch 625: [ 0.00666025]
# Error of the epoch 626: [ 0.00665823]
# Error of the epoch 627: [ 0.00665622]
# Error of the epoch 628: [ 0.00665421]
# Error of the epoch 629: [ 0.00665221]
# Error of the epoch 630: [ 0.00665021]
# Error of the epoch 631: [ 0.00664822]
# Error of the epoch 632: [ 0.00664623]
# Error of the epoch 633: [ 0.00664425]
# Error of the epoch 634: [ 0.00664227]
# Error of the epoch 635: [ 0.00664029]
# Error of the epoch 636: [ 0.00663832]
# Error of the epoch 637: [ 0.00663636]
# Error of the epoch 638: [ 0.0066344]
# Error of the epoch 639: [ 0.00663244]
# Error of the epoch 640: [ 0.00663049]
# Error of the epoch 641: [ 0.00662855]
# Error of the epoch 642: [ 0.0066266]
# Error of the epoch 643: [ 0.00662467]
# Error of the epoch 644: [ 0.00662273]
# Error of the epoch 645: [ 0.00662081]
# Error of the epoch 646: [ 0.00661888]
# Error of the epoch 647: [ 0.00661697]
# Error of the epoch 648: [ 0.00661505]
# Error of the epoch 649: [ 0.00661314]
# Error of the epoch 650: [ 0.00661124]
# Error of the epoch 651: [ 0.00660934]
# Error of the epoch 652: [ 0.00660744]
# Error of the epoch 653: [ 0.00660555]
# Error of the epoch 654: [ 0.00660366]
# Error of the epoch 655: [ 0.00660178]
# Error of the epoch 656: [ 0.0065999]
# Error of the epoch 657: [ 0.00659803]
# Error of the epoch 658: [ 0.00659616]
# Error of the epoch 659: [ 0.0065943]
# Error of the epoch 660: [ 0.00659244]
# Error of the epoch 661: [ 0.00659058]
# Error of the epoch 662: [ 0.00658873]
# Error of the epoch 663: [ 0.00658688]
# Error of the epoch 664: [ 0.00658504]
# Error of the epoch 665: [ 0.0065832]
# Error of the epoch 666: [ 0.00658137]
# Error of the epoch 667: [ 0.00657954]
# Error of the epoch 668: [ 0.00657772]
# Error of the epoch 669: [ 0.00657589]
# Error of the epoch 670: [ 0.00657408]
# Error of the epoch 671: [ 0.00657227]
# Error of the epoch 672: [ 0.00657046]
# Error of the epoch 673: [ 0.00656865]
# Error of the epoch 674: [ 0.00656685]
# Error of the epoch 675: [ 0.00656506]
# Error of the epoch 676: [ 0.00656327]
# Error of the epoch 677: [ 0.00656148]
# Error of the epoch 678: [ 0.0065597]
# Error of the epoch 679: [ 0.00655792]
# Error of the epoch 680: [ 0.00655615]
# Error of the epoch 681: [ 0.00655438]
# Error of the epoch 682: [ 0.00655261]
# Error of the epoch 683: [ 0.00655085]
# Error of the epoch 684: [ 0.00654909]
# Error of the epoch 685: [ 0.00654734]
# Error of the epoch 686: [ 0.00654559]
# Error of the epoch 687: [ 0.00654384]
# Error of the epoch 688: [ 0.0065421]
# Error of the epoch 689: [ 0.00654036]
# Error of the epoch 690: [ 0.00653863]
# Error of the epoch 691: [ 0.0065369]
# Error of the epoch 692: [ 0.00653518]
# Error of the epoch 693: [ 0.00653345]
# Error of the epoch 694: [ 0.00653174]
# Error of the epoch 695: [ 0.00653002]
# Error of the epoch 696: [ 0.00652831]
# Error of the epoch 697: [ 0.00652661]
# Error of the epoch 698: [ 0.00652491]
# Error of the epoch 699: [ 0.00652321]
# Error of the epoch 700: [ 0.00652152]
# Error of the epoch 701: [ 0.00651983]
# Error of the epoch 702: [ 0.00651814]
# Error of the epoch 703: [ 0.00651646]
# Error of the epoch 704: [ 0.00651478]
# Error of the epoch 705: [ 0.00651311]
# Error of the epoch 706: [ 0.00651144]
# Error of the epoch 707: [ 0.00650977]
# Error of the epoch 708: [ 0.00650811]
# Error of the epoch 709: [ 0.00650645]
# Error of the epoch 710: [ 0.0065048]
# Error of the epoch 711: [ 0.00650315]
# Error of the epoch 712: [ 0.0065015]
# Error of the epoch 713: [ 0.00649986]
# Error of the epoch 714: [ 0.00649822]
# Error of the epoch 715: [ 0.00649658]
# Error of the epoch 716: [ 0.00649495]
# Error of the epoch 717: [ 0.00649332]
# Error of the epoch 718: [ 0.0064917]
# Error of the epoch 719: [ 0.00649008]
# Error of the epoch 720: [ 0.00648846]
# Error of the epoch 721: [ 0.00648684]
# Error of the epoch 722: [ 0.00648524]
# Error of the epoch 723: [ 0.00648363]
# Error of the epoch 724: [ 0.00648203]
# Error of the epoch 725: [ 0.00648043]
# Error of the epoch 726: [ 0.00647883]
# Error of the epoch 727: [ 0.00647724]
# Error of the epoch 728: [ 0.00647565]
# Error of the epoch 729: [ 0.00647407]
# Error of the epoch 730: [ 0.00647249]
# Error of the epoch 731: [ 0.00647091]
# Error of the epoch 732: [ 0.00646934]
# Error of the epoch 733: [ 0.00646777]
# Error of the epoch 734: [ 0.0064662]
# Error of the epoch 735: [ 0.00646464]
# Error of the epoch 736: [ 0.00646308]
# Error of the epoch 737: [ 0.00646153]
# Error of the epoch 738: [ 0.00645997]
# Error of the epoch 739: [ 0.00645843]
# Error of the epoch 740: [ 0.00645688]
# Error of the epoch 741: [ 0.00645534]
# Error of the epoch 742: [ 0.0064538]
# Error of the epoch 743: [ 0.00645227]
# Error of the epoch 744: [ 0.00645074]
# Error of the epoch 745: [ 0.00644921]
# Error of the epoch 746: [ 0.00644769]
# Error of the epoch 747: [ 0.00644616]
# Error of the epoch 748: [ 0.00644465]
# Error of the epoch 749: [ 0.00644313]
# Error of the epoch 750: [ 0.00644162]
# Error of the epoch 751: [ 0.00644012]
# Error of the epoch 752: [ 0.00643861]
# Error of the epoch 753: [ 0.00643711]
# Error of the epoch 754: [ 0.00643562]
# Error of the epoch 755: [ 0.00643412]
# Error of the epoch 756: [ 0.00643263]
# Error of the epoch 757: [ 0.00643115]
# Error of the epoch 758: [ 0.00642966]
# Error of the epoch 759: [ 0.00642818]
# Error of the epoch 760: [ 0.00642671]
# Error of the epoch 761: [ 0.00642523]
# Error of the epoch 762: [ 0.00642376]
# Error of the epoch 763: [ 0.0064223]
# Error of the epoch 764: [ 0.00642083]
# Error of the epoch 765: [ 0.00641937]
# Error of the epoch 766: [ 0.00641791]
# Error of the epoch 767: [ 0.00641646]
# Error of the epoch 768: [ 0.00641501]
# Error of the epoch 769: [ 0.00641356]
# Error of the epoch 770: [ 0.00641212]
# Error of the epoch 771: [ 0.00641068]
# Error of the epoch 772: [ 0.00640924]
# Error of the epoch 773: [ 0.00640781]
# Error of the epoch 774: [ 0.00640637]
# Error of the epoch 775: [ 0.00640495]
# Error of the epoch 776: [ 0.00640352]
# Error of the epoch 777: [ 0.0064021]
# Error of the epoch 778: [ 0.00640068]
# Error of the epoch 779: [ 0.00639927]
# Error of the epoch 780: [ 0.00639785]
# Error of the epoch 781: [ 0.00639644]
# Error of the epoch 782: [ 0.00639504]
# Error of the epoch 783: [ 0.00639364]
# Error of the epoch 784: [ 0.00639224]
# Error of the epoch 785: [ 0.00639084]
# Error of the epoch 786: [ 0.00638945]
# Error of the epoch 787: [ 0.00638805]
# Error of the epoch 788: [ 0.00638667]
# Error of the epoch 789: [ 0.00638528]
# Error of the epoch 790: [ 0.0063839]
# Error of the epoch 791: [ 0.00638252]
# Error of the epoch 792: [ 0.00638115]
# Error of the epoch 793: [ 0.00637978]
# Error of the epoch 794: [ 0.00637841]
# Error of the epoch 795: [ 0.00637704]
# Error of the epoch 796: [ 0.00637568]
# Error of the epoch 797: [ 0.00637432]
# Error of the epoch 798: [ 0.00637296]
# Error of the epoch 799: [ 0.0063716]
# Error of the epoch 800: [ 0.00637025]
# Error of the epoch 801: [ 0.00636891]
# Error of the epoch 802: [ 0.00636756]
# Error of the epoch 803: [ 0.00636622]
# Error of the epoch 804: [ 0.00636488]
# Error of the epoch 805: [ 0.00636354]
# Error of the epoch 806: [ 0.00636221]
# Error of the epoch 807: [ 0.00636088]
# Error of the epoch 808: [ 0.00635955]
# Error of the epoch 809: [ 0.00635822]
# Error of the epoch 810: [ 0.0063569]
# Error of the epoch 811: [ 0.00635558]
# Error of the epoch 812: [ 0.00635427]
# Error of the epoch 813: [ 0.00635295]
# Error of the epoch 814: [ 0.00635164]
# Error of the epoch 815: [ 0.00635033]
# Error of the epoch 816: [ 0.00634903]
# Error of the epoch 817: [ 0.00634773]
# Error of the epoch 818: [ 0.00634643]
# Error of the epoch 819: [ 0.00634513]
# Error of the epoch 820: [ 0.00634384]
# Error of the epoch 821: [ 0.00634255]
# Error of the epoch 822: [ 0.00634126]
# Error of the epoch 823: [ 0.00633997]
# Error of the epoch 824: [ 0.00633869]
# Error of the epoch 825: [ 0.00633741]
# Error of the epoch 826: [ 0.00633614]
# Error of the epoch 827: [ 0.00633486]
# Error of the epoch 828: [ 0.00633359]
# Error of the epoch 829: [ 0.00633232]
# Error of the epoch 830: [ 0.00633106]
# Error of the epoch 831: [ 0.00632979]
# Error of the epoch 832: [ 0.00632853]
# Error of the epoch 833: [ 0.00632727]
# Error of the epoch 834: [ 0.00632602]
# Error of the epoch 835: [ 0.00632477]
# Error of the epoch 836: [ 0.00632352]
# Error of the epoch 837: [ 0.00632227]
# Error of the epoch 838: [ 0.00632103]
# Error of the epoch 839: [ 0.00631978]
# Error of the epoch 840: [ 0.00631855]
# Error of the epoch 841: [ 0.00631731]
# Error of the epoch 842: [ 0.00631608]
# Error of the epoch 843: [ 0.00631485]
# Error of the epoch 844: [ 0.00631362]
# Error of the epoch 845: [ 0.00631239]
# Error of the epoch 846: [ 0.00631117]
# Error of the epoch 847: [ 0.00630995]
# Error of the epoch 848: [ 0.00630873]
# Error of the epoch 849: [ 0.00630751]
# Error of the epoch 850: [ 0.0063063]
# Error of the epoch 851: [ 0.00630509]
# Error of the epoch 852: [ 0.00630388]
# Error of the epoch 853: [ 0.00630268]
# Error of the epoch 854: [ 0.00630148]
# Error of the epoch 855: [ 0.00630028]
# Error of the epoch 856: [ 0.00629908]
# Error of the epoch 857: [ 0.00629789]
# Error of the epoch 858: [ 0.00629669]
# Error of the epoch 859: [ 0.0062955]
# Error of the epoch 860: [ 0.00629432]
# Error of the epoch 861: [ 0.00629313]
# Error of the epoch 862: [ 0.00629195]
# Error of the epoch 863: [ 0.00629077]
# Error of the epoch 864: [ 0.00628959]
# Error of the epoch 865: [ 0.00628842]
# Error of the epoch 866: [ 0.00628725]
# Error of the epoch 867: [ 0.00628608]
# Error of the epoch 868: [ 0.00628491]
# Error of the epoch 869: [ 0.00628375]
# Error of the epoch 870: [ 0.00628258]
# Error of the epoch 871: [ 0.00628142]
# Error of the epoch 872: [ 0.00628027]
# Error of the epoch 873: [ 0.00627911]
# Error of the epoch 874: [ 0.00627796]
# Error of the epoch 875: [ 0.00627681]
# Error of the epoch 876: [ 0.00627566]
# Error of the epoch 877: [ 0.00627452]
# Error of the epoch 878: [ 0.00627337]
# Error of the epoch 879: [ 0.00627223]
# Error of the epoch 880: [ 0.0062711]
# Error of the epoch 881: [ 0.00626996]
# Error of the epoch 882: [ 0.00626883]
# Error of the epoch 883: [ 0.0062677]
# Error of the epoch 884: [ 0.00626657]
# Error of the epoch 885: [ 0.00626544]
# Error of the epoch 886: [ 0.00626432]
# Error of the epoch 887: [ 0.0062632]
# Error of the epoch 888: [ 0.00626208]
# Error of the epoch 889: [ 0.00626096]
# Error of the epoch 890: [ 0.00625985]
# Error of the epoch 891: [ 0.00625874]
# Error of the epoch 892: [ 0.00625763]
# Error of the epoch 893: [ 0.00625652]
# Error of the epoch 894: [ 0.00625541]
# Error of the epoch 895: [ 0.00625431]
# Error of the epoch 896: [ 0.00625321]
# Error of the epoch 897: [ 0.00625211]
# Error of the epoch 898: [ 0.00625102]
# Error of the epoch 899: [ 0.00624992]
# Error of the epoch 900: [ 0.00624883]
# Error of the epoch 901: [ 0.00624774]
# Error of the epoch 902: [ 0.00624666]
# Error of the epoch 903: [ 0.00624557]
# Error of the epoch 904: [ 0.00624449]
# Error of the epoch 905: [ 0.00624341]
# Error of the epoch 906: [ 0.00624233]
# Error of the epoch 907: [ 0.00624126]
# Error of the epoch 908: [ 0.00624018]
# Error of the epoch 909: [ 0.00623911]
# Error of the epoch 910: [ 0.00623805]
# Error of the epoch 911: [ 0.00623698]
# Error of the epoch 912: [ 0.00623591]
# Error of the epoch 913: [ 0.00623485]
# Error of the epoch 914: [ 0.00623379]
# Error of the epoch 915: [ 0.00623273]
# Error of the epoch 916: [ 0.00623168]
# Error of the epoch 917: [ 0.00623063]
# Error of the epoch 918: [ 0.00622957]
# Error of the epoch 919: [ 0.00622853]
# Error of the epoch 920: [ 0.00622748]
# Error of the epoch 921: [ 0.00622643]
# Error of the epoch 922: [ 0.00622539]
# Error of the epoch 923: [ 0.00622435]
# Error of the epoch 924: [ 0.00622331]
# Error of the epoch 925: [ 0.00622228]
# Error of the epoch 926: [ 0.00622124]
# Error of the epoch 927: [ 0.00622021]
# Error of the epoch 928: [ 0.00621918]
# Error of the epoch 929: [ 0.00621815]
# Error of the epoch 930: [ 0.00621713]
# Error of the epoch 931: [ 0.0062161]
# Error of the epoch 932: [ 0.00621508]
# Error of the epoch 933: [ 0.00621406]
# Error of the epoch 934: [ 0.00621305]
# Error of the epoch 935: [ 0.00621203]
# Error of the epoch 936: [ 0.00621102]
# Error of the epoch 937: [ 0.00621001]
# Error of the epoch 938: [ 0.006209]
# Error of the epoch 939: [ 0.00620799]
# Error of the epoch 940: [ 0.00620699]
# Error of the epoch 941: [ 0.00620598]
# Error of the epoch 942: [ 0.00620498]
# Error of the epoch 943: [ 0.00620398]
# Error of the epoch 944: [ 0.00620299]
# Error of the epoch 945: [ 0.00620199]
# Error of the epoch 946: [ 0.006201]
# Error of the epoch 947: [ 0.00620001]
# Error of the epoch 948: [ 0.00619902]
# Error of the epoch 949: [ 0.00619803]
# Error of the epoch 950: [ 0.00619705]
# Error of the epoch 951: [ 0.00619607]
# Error of the epoch 952: [ 0.00619509]
# Error of the epoch 953: [ 0.00619411]
# Error of the epoch 954: [ 0.00619313]
# Error of the epoch 955: [ 0.00619216]
# Error of the epoch 956: [ 0.00619118]
# Error of the epoch 957: [ 0.00619021]
# Error of the epoch 958: [ 0.00618924]
# Error of the epoch 959: [ 0.00618828]
# Error of the epoch 960: [ 0.00618731]
# Error of the epoch 961: [ 0.00618635]
# Error of the epoch 962: [ 0.00618539]
# Error of the epoch 963: [ 0.00618443]
# Error of the epoch 964: [ 0.00618347]
# Error of the epoch 965: [ 0.00618252]
# Error of the epoch 966: [ 0.00618157]
# Error of the epoch 967: [ 0.00618061]
# Error of the epoch 968: [ 0.00617966]
# Error of the epoch 969: [ 0.00617872]
# Error of the epoch 970: [ 0.00617777]
# Error of the epoch 971: [ 0.00617683]
# Error of the epoch 972: [ 0.00617589]
# Error of the epoch 973: [ 0.00617495]
# Error of the epoch 974: [ 0.00617401]
# Error of the epoch 975: [ 0.00617307]
# Error of the epoch 976: [ 0.00617214]
# Error of the epoch 977: [ 0.00617121]
# Error of the epoch 978: [ 0.00617028]
# Error of the epoch 979: [ 0.00616935]
# Error of the epoch 980: [ 0.00616842]
# Error of the epoch 981: [ 0.00616749]
# Error of the epoch 982: [ 0.00616657]
# Error of the epoch 983: [ 0.00616565]
# Error of the epoch 984: [ 0.00616473]
# Error of the epoch 985: [ 0.00616381]
# Error of the epoch 986: [ 0.0061629]
# Error of the epoch 987: [ 0.00616198]
# Error of the epoch 988: [ 0.00616107]
# Error of the epoch 989: [ 0.00616016]
# Error of the epoch 990: [ 0.00615925]
# Error of the epoch 991: [ 0.00615835]
# Error of the epoch 992: [ 0.00615744]
# Error of the epoch 993: [ 0.00615654]
# Error of the epoch 994: [ 0.00615564]
# Error of the epoch 995: [ 0.00615474]
# Error of the epoch 996: [ 0.00615384]
# Error of the epoch 997: [ 0.00615294]
# Error of the epoch 998: [ 0.00615205]
# Error of the epoch 999: [ 0.00615116]
# Error of the epoch 1000: [ 0.00615027]
# Accuracy of our LLSR:98.6%

# %% [markdown]
# One thing to compare: the speed. Try to run the same number of epochs (1000) with SGD, vectorized training, you can see it still takes a long time to run compared to the fully batch training.

# %%
w, b = train_vectorized(X_train, Y_train, epochs=1000)
_ = test_vectorized(X_test, Y_test, w, b)
# Out:
# Error of the epoch 1: [ 0.01169449]
# Error of the epoch 2: [ 0.00879146]
# Error of the epoch 3: [ 0.00833166]
# Error of the epoch 4: [ 0.00814921]
# Error of the epoch 5: [ 0.00805634]
# Error of the epoch 6: [ 0.00800113]
# Error of the epoch 7: [ 0.00796388]
# Error of the epoch 8: [ 0.00793627]
# Error of the epoch 9: [ 0.00791453]
# Error of the epoch 10: [ 0.00789692]
# Error of the epoch 11: [ 0.00788258]
# Error of the epoch 12: [ 0.00787101]
# Error of the epoch 13: [ 0.00786176]
# Error of the epoch 14: [ 0.00785442]
# Error of the epoch 15: [ 0.00784861]
# Error of the epoch 16: [ 0.00784401]
# Error of the epoch 17: [ 0.00784036]
# Error of the epoch 18: [ 0.00783746]
# Error of the epoch 19: [ 0.00783513]
# Error of the epoch 20: [ 0.00783327]
# Error of the epoch 21: [ 0.00783176]
# Error of the epoch 22: [ 0.00783053]
# Error of the epoch 23: [ 0.00782954]
# Error of the epoch 24: [ 0.00782872]
# Error of the epoch 25: [ 0.00782806]
# Error of the epoch 26: [ 0.00782751]
# Error of the epoch 27: [ 0.00782705]
# Error of the epoch 28: [ 0.00782667]
# Error of the epoch 29: [ 0.00782636]
# Error of the epoch 30: [ 0.00782609]
# Error of the epoch 31: [ 0.00782587]
# Error of the epoch 32: [ 0.00782569]
# Error of the epoch 33: [ 0.00782553]
# Error of the epoch 34: [ 0.0078254]
# Error of the epoch 35: [ 0.00782529]
# Error of the epoch 36: [ 0.00782519]
# Error of the epoch 37: [ 0.00782511]
# Error of the epoch 38: [ 0.00782504]
# Error of the epoch 39: [ 0.00782498]
# Error of the epoch 40: [ 0.00782493]
# Error of the epoch 41: [ 0.00782489]
# Error of the epoch 42: [ 0.00782485]
# Error of the epoch 43: [ 0.00782482]
# Error of the epoch 44: [ 0.00782479]
# Error of the epoch 45: [ 0.00782477]
# Error of the epoch 46: [ 0.00782475]
# Error of the epoch 47: [ 0.00782473]
# Error of the epoch 48: [ 0.00782472]
# Error of the epoch 49: [ 0.0078247]
# Error of the epoch 50: [ 0.00782469]
# Error of the epoch 51: [ 0.00782468]
# Error of the epoch 52: [ 0.00782467]
# Error of the epoch 53: [ 0.00782467]
# Error of the epoch 54: [ 0.00782466]
# Error of the epoch 55: [ 0.00782465]
# Error of the epoch 56: [ 0.00782465]
# Error of the epoch 57: [ 0.00782465]
# Error of the epoch 58: [ 0.00782464]
# Error of the epoch 59: [ 0.00782464]
# Error of the epoch 60: [ 0.00782464]
# Error of the epoch 61: [ 0.00782463]
# Error of the epoch 62: [ 0.00782463]
# Error of the epoch 63: [ 0.00782463]
# Error of the epoch 64: [ 0.00782463]
# Error of the epoch 65: [ 0.00782463]
# Error of the epoch 66: [ 0.00782463]
# Error of the epoch 67: [ 0.00782462]
# Error of the epoch 68: [ 0.00782462]
# Error of the epoch 69: [ 0.00782462]
# Error of the epoch 70: [ 0.00782462]
# Error of the epoch 71: [ 0.00782462]
# Error of the epoch 72: [ 0.00782462]
# Error of the epoch 73: [ 0.00782462]
# Error of the epoch 74: [ 0.00782462]
# Error of the epoch 75: [ 0.00782462]
# Error of the epoch 76: [ 0.00782462]
# Error of the epoch 77: [ 0.00782462]
# Error of the epoch 78: [ 0.00782462]
# Error of the epoch 79: [ 0.00782462]
# Error of the epoch 80: [ 0.00782462]
# Error of the epoch 81: [ 0.00782462]
# Error of the epoch 82: [ 0.00782462]
# Error of the epoch 83: [ 0.00782462]
# Error of the epoch 84: [ 0.00782462]
# Error of the epoch 85: [ 0.00782462]
# Error of the epoch 86: [ 0.00782462]
# Error of the epoch 87: [ 0.00782462]
# Error of the epoch 88: [ 0.00782462]
# Error of the epoch 89: [ 0.00782462]
# Error of the epoch 90: [ 0.00782462]
# Error of the epoch 91: [ 0.00782462]
# Error of the epoch 92: [ 0.00782462]
# Error of the epoch 93: [ 0.00782462]
# Error of the epoch 94: [ 0.00782462]
# Error of the epoch 95: [ 0.00782462]
# Error of the epoch 96: [ 0.00782462]
# Error of the epoch 97: [ 0.00782462]
# Error of the epoch 98: [ 0.00782462]
# Error of the epoch 99: [ 0.00782462]
# Error of the epoch 100: [ 0.00782462]
# Error of the epoch 101: [ 0.00782462]
# Error of the epoch 102: [ 0.00782462]
# Error of the epoch 103: [ 0.00782462]
# Error of the epoch 104: [ 0.00782462]
# Error of the epoch 105: [ 0.00782462]
# Error of the epoch 106: [ 0.00782462]
# Error of the epoch 107: [ 0.00782462]
# Error of the epoch 108: [ 0.00782462]
# Error of the epoch 109: [ 0.00782462]
# Error of the epoch 110: [ 0.00782462]
# Error of the epoch 111: [ 0.00782462]
# Error of the epoch 112: [ 0.00782462]
# Error of the epoch 113: [ 0.00782462]
# Error of the epoch 114: [ 0.00782462]
# Error of the epoch 115: [ 0.00782462]
# Error of the epoch 116: [ 0.00782462]
# Error of the epoch 117: [ 0.00782462]
# Error of the epoch 118: [ 0.00782462]
# Error of the epoch 119: [ 0.00782462]
# Error of the epoch 120: [ 0.00782462]
# Error of the epoch 121: [ 0.00782462]
# Error of the epoch 122: [ 0.00782462]
# Error of the epoch 123: [ 0.00782462]
# Error of the epoch 124: [ 0.00782462]
# Error of the epoch 125: [ 0.00782462]
# Error of the epoch 126: [ 0.00782462]
# Error of the epoch 127: [ 0.00782462]
# Error of the epoch 128: [ 0.00782462]
# Error of the epoch 129: [ 0.00782462]
# Error of the epoch 130: [ 0.00782462]
# Error of the epoch 131: [ 0.00782462]
# Error of the epoch 132: [ 0.00782462]
# Error of the epoch 133: [ 0.00782462]
# Error of the epoch 134: [ 0.00782462]
# Error of the epoch 135: [ 0.00782462]
# Error of the epoch 136: [ 0.00782462]
# Error of the epoch 137: [ 0.00782462]
# Error of the epoch 138: [ 0.00782462]
# Error of the epoch 139: [ 0.00782462]
# Error of the epoch 140: [ 0.00782462]
# Error of the epoch 141: [ 0.00782462]
# Error of the epoch 142: [ 0.00782462]
# Error of the epoch 143: [ 0.00782462]
# Error of the epoch 144: [ 0.00782462]
# Error of the epoch 145: [ 0.00782462]
# Error of the epoch 146: [ 0.00782462]
# Error of the epoch 147: [ 0.00782462]
# Error of the epoch 148: [ 0.00782462]
# Error of the epoch 149: [ 0.00782462]
# Error of the epoch 150: [ 0.00782462]
# Error of the epoch 151: [ 0.00782462]
# Error of the epoch 152: [ 0.00782462]
# Error of the epoch 153: [ 0.00782462]
# Error of the epoch 154: [ 0.00782462]
# Error of the epoch 155: [ 0.00782462]
# Error of the epoch 156: [ 0.00782462]
# Error of the epoch 157: [ 0.00782462]
# Error of the epoch 158: [ 0.00782462]
# Error of the epoch 159: [ 0.00782462]
# Error of the epoch 160: [ 0.00782462]
# Error of the epoch 161: [ 0.00782462]
# Error of the epoch 162: [ 0.00782462]
# Error of the epoch 163: [ 0.00782462]
# Error of the epoch 164: [ 0.00782462]
# Error of the epoch 165: [ 0.00782462]
# Error of the epoch 166: [ 0.00782462]
# Error of the epoch 167: [ 0.00782462]
# Error of the epoch 168: [ 0.00782462]
# Error of the epoch 169: [ 0.00782462]
# Error of the epoch 170: [ 0.00782462]
# Error of the epoch 171: [ 0.00782462]
# Error of the epoch 172: [ 0.00782462]
# Error of the epoch 173: [ 0.00782462]
# Error of the epoch 174: [ 0.00782462]
# Error of the epoch 175: [ 0.00782462]
# Error of the epoch 176: [ 0.00782462]
# Error of the epoch 177: [ 0.00782462]
# Error of the epoch 178: [ 0.00782462]
# Error of the epoch 179: [ 0.00782462]
# Error of the epoch 180: [ 0.00782462]
# Error of the epoch 181: [ 0.00782462]
# Error of the epoch 182: [ 0.00782462]
# Error of the epoch 183: [ 0.00782462]
# Error of the epoch 184: [ 0.00782462]
# Error of the epoch 185: [ 0.00782462]
# Error of the epoch 186: [ 0.00782462]
# Error of the epoch 187: [ 0.00782462]
# Error of the epoch 188: [ 0.00782462]
# Error of the epoch 189: [ 0.00782462]
# Error of the epoch 190: [ 0.00782462]
# Error of the epoch 191: [ 0.00782462]
# Error of the epoch 192: [ 0.00782462]
# Error of the epoch 193: [ 0.00782462]
# Error of the epoch 194: [ 0.00782462]
# Error of the epoch 195: [ 0.00782462]
# Error of the epoch 196: [ 0.00782462]
# Error of the epoch 197: [ 0.00782462]
# Error of the epoch 198: [ 0.00782462]
# Error of the epoch 199: [ 0.00782462]
# Error of the epoch 200: [ 0.00782462]
# Error of the epoch 201: [ 0.00782462]
# Error of the epoch 202: [ 0.00782462]
# Error of the epoch 203: [ 0.00782462]
# Error of the epoch 204: [ 0.00782462]
# Error of the epoch 205: [ 0.00782462]
# Error of the epoch 206: [ 0.00782462]
# Error of the epoch 207: [ 0.00782462]
# Error of the epoch 208: [ 0.00782462]
# Error of the epoch 209: [ 0.00782462]
# Error of the epoch 210: [ 0.00782462]
# Error of the epoch 211: [ 0.00782462]
# Error of the epoch 212: [ 0.00782462]
# Error of the epoch 213: [ 0.00782462]
# Error of the epoch 214: [ 0.00782462]
# Error of the epoch 215: [ 0.00782462]
# Error of the epoch 216: [ 0.00782462]
# Error of the epoch 217: [ 0.00782462]
# Error of the epoch 218: [ 0.00782462]
# Error of the epoch 219: [ 0.00782462]
# Error of the epoch 220: [ 0.00782462]
# Error of the epoch 221: [ 0.00782462]
# Error of the epoch 222: [ 0.00782462]
# Error of the epoch 223: [ 0.00782462]
# Error of the epoch 224: [ 0.00782462]
# Error of the epoch 225: [ 0.00782462]
# Error of the epoch 226: [ 0.00782462]
# Error of the epoch 227: [ 0.00782462]
# Error of the epoch 228: [ 0.00782462]
# Error of the epoch 229: [ 0.00782462]
# Error of the epoch 230: [ 0.00782462]
# Error of the epoch 231: [ 0.00782462]
# Error of the epoch 232: [ 0.00782462]
# Error of the epoch 233: [ 0.00782462]
# Error of the epoch 234: [ 0.00782462]
# Error of the epoch 235: [ 0.00782462]
# Error of the epoch 236: [ 0.00782462]
# Error of the epoch 237: [ 0.00782462]
# Error of the epoch 238: [ 0.00782462]
# Error of the epoch 239: [ 0.00782462]
# Error of the epoch 240: [ 0.00782462]
# Error of the epoch 241: [ 0.00782462]
# Error of the epoch 242: [ 0.00782462]
# Error of the epoch 243: [ 0.00782462]
# Error of the epoch 244: [ 0.00782462]
# Error of the epoch 245: [ 0.00782462]
# Error of the epoch 246: [ 0.00782462]
# Error of the epoch 247: [ 0.00782462]
# Error of the epoch 248: [ 0.00782462]
# Error of the epoch 249: [ 0.00782462]
# Error of the epoch 250: [ 0.00782462]
# Error of the epoch 251: [ 0.00782462]
# Error of the epoch 252: [ 0.00782462]
# Error of the epoch 253: [ 0.00782462]
# Error of the epoch 254: [ 0.00782462]
# Error of the epoch 255: [ 0.00782462]
# Error of the epoch 256: [ 0.00782462]
# Error of the epoch 257: [ 0.00782462]
# Error of the epoch 258: [ 0.00782462]
# Error of the epoch 259: [ 0.00782462]
# Error of the epoch 260: [ 0.00782462]
# Error of the epoch 261: [ 0.00782462]
# Error of the epoch 262: [ 0.00782462]
# Error of the epoch 263: [ 0.00782462]
# Error of the epoch 264: [ 0.00782462]
# Error of the epoch 265: [ 0.00782462]
# Error of the epoch 266: [ 0.00782462]
# Error of the epoch 267: [ 0.00782462]
# Error of the epoch 268: [ 0.00782462]
# Error of the epoch 269: [ 0.00782462]
# Error of the epoch 270: [ 0.00782462]
# Error of the epoch 271: [ 0.00782462]
# Error of the epoch 272: [ 0.00782462]
# Error of the epoch 273: [ 0.00782462]
# Error of the epoch 274: [ 0.00782462]
# Error of the epoch 275: [ 0.00782462]
# Error of the epoch 276: [ 0.00782462]
# Error of the epoch 277: [ 0.00782462]
# Error of the epoch 278: [ 0.00782462]
# Error of the epoch 279: [ 0.00782462]
# Error of the epoch 280: [ 0.00782462]
# Error of the epoch 281: [ 0.00782462]
# Error of the epoch 282: [ 0.00782462]
# Error of the epoch 283: [ 0.00782462]
# Error of the epoch 284: [ 0.00782462]
# Error of the epoch 285: [ 0.00782462]
# Error of the epoch 286: [ 0.00782462]
# Error of the epoch 287: [ 0.00782462]
# Error of the epoch 288: [ 0.00782462]
# Error of the epoch 289: [ 0.00782462]
# Error of the epoch 290: [ 0.00782462]
# Error of the epoch 291: [ 0.00782462]
# Error of the epoch 292: [ 0.00782462]
# Error of the epoch 293: [ 0.00782462]
# Error of the epoch 294: [ 0.00782462]
# Error of the epoch 295: [ 0.00782462]
# Error of the epoch 296: [ 0.00782462]
# Error of the epoch 297: [ 0.00782462]
# Error of the epoch 298: [ 0.00782462]
# Error of the epoch 299: [ 0.00782462]
# Error of the epoch 300: [ 0.00782462]
# Error of the epoch 301: [ 0.00782462]
# Error of the epoch 302: [ 0.00782462]
# Error of the epoch 303: [ 0.00782462]
# Error of the epoch 304: [ 0.00782462]
# Error of the epoch 305: [ 0.00782462]
# Error of the epoch 306: [ 0.00782462]
# Error of the epoch 307: [ 0.00782462]
# Error of the epoch 308: [ 0.00782462]
# Error of the epoch 309: [ 0.00782462]
# Error of the epoch 310: [ 0.00782462]
# Error of the epoch 311: [ 0.00782462]
# Error of the epoch 312: [ 0.00782462]
# Error of the epoch 313: [ 0.00782462]
# Error of the epoch 314: [ 0.00782462]
# Error of the epoch 315: [ 0.00782462]
# Error of the epoch 316: [ 0.00782462]
# Error of the epoch 317: [ 0.00782462]
# Error of the epoch 318: [ 0.00782462]
# Error of the epoch 319: [ 0.00782462]
# Error of the epoch 320: [ 0.00782462]
# Error of the epoch 321: [ 0.00782462]
# Error of the epoch 322: [ 0.00782462]
# Error of the epoch 323: [ 0.00782462]
# Error of the epoch 324: [ 0.00782462]
# Error of the epoch 325: [ 0.00782462]
# Error of the epoch 326: [ 0.00782462]
# Error of the epoch 327: [ 0.00782462]
# Error of the epoch 328: [ 0.00782462]
# Error of the epoch 329: [ 0.00782462]
# Error of the epoch 330: [ 0.00782462]
# Error of the epoch 331: [ 0.00782462]
# Error of the epoch 332: [ 0.00782462]
# Error of the epoch 333: [ 0.00782462]
# Error of the epoch 334: [ 0.00782462]
# Error of the epoch 335: [ 0.00782462]
# Error of the epoch 336: [ 0.00782462]
# Error of the epoch 337: [ 0.00782462]
# Error of the epoch 338: [ 0.00782462]
# Error of the epoch 339: [ 0.00782462]
# Error of the epoch 340: [ 0.00782462]
# Error of the epoch 341: [ 0.00782462]
# Error of the epoch 342: [ 0.00782462]
# Error of the epoch 343: [ 0.00782462]
# Error of the epoch 344: [ 0.00782462]
# Error of the epoch 345: [ 0.00782462]
# Error of the epoch 346: [ 0.00782462]
# Error of the epoch 347: [ 0.00782462]
# Error of the epoch 348: [ 0.00782462]
# Error of the epoch 349: [ 0.00782462]
# Error of the epoch 350: [ 0.00782462]
# Error of the epoch 351: [ 0.00782462]
# Error of the epoch 352: [ 0.00782462]
# Error of the epoch 353: [ 0.00782462]
# Error of the epoch 354: [ 0.00782462]
# Error of the epoch 355: [ 0.00782462]
# Error of the epoch 356: [ 0.00782462]
# Error of the epoch 357: [ 0.00782462]
# Error of the epoch 358: [ 0.00782462]
# Error of the epoch 359: [ 0.00782462]
# Error of the epoch 360: [ 0.00782462]
# Error of the epoch 361: [ 0.00782462]
# Error of the epoch 362: [ 0.00782462]
# Error of the epoch 363: [ 0.00782462]
# Error of the epoch 364: [ 0.00782462]
# Error of the epoch 365: [ 0.00782462]
# Error of the epoch 366: [ 0.00782462]
# Error of the epoch 367: [ 0.00782462]
# Error of the epoch 368: [ 0.00782462]
# Error of the epoch 369: [ 0.00782462]
# Error of the epoch 370: [ 0.00782462]
# Error of the epoch 371: [ 0.00782462]
# Error of the epoch 372: [ 0.00782462]
# Error of the epoch 373: [ 0.00782462]
# Error of the epoch 374: [ 0.00782462]
# Error of the epoch 375: [ 0.00782462]
# Error of the epoch 376: [ 0.00782462]
# Error of the epoch 377: [ 0.00782462]
# Error of the epoch 378: [ 0.00782462]
# Error of the epoch 379: [ 0.00782462]
# Error of the epoch 380: [ 0.00782462]
# Error of the epoch 381: [ 0.00782462]
# Error of the epoch 382: [ 0.00782462]
# Error of the epoch 383: [ 0.00782462]
# Error of the epoch 384: [ 0.00782462]
# Error of the epoch 385: [ 0.00782462]
# Error of the epoch 386: [ 0.00782462]
# Error of the epoch 387: [ 0.00782462]
# Error of the epoch 388: [ 0.00782462]
# Error of the epoch 389: [ 0.00782462]
# Error of the epoch 390: [ 0.00782462]
# Error of the epoch 391: [ 0.00782462]
# Error of the epoch 392: [ 0.00782462]
# Error of the epoch 393: [ 0.00782462]
# Error of the epoch 394: [ 0.00782462]
# Error of the epoch 395: [ 0.00782462]
# Error of the epoch 396: [ 0.00782462]
# Error of the epoch 397: [ 0.00782462]
# Error of the epoch 398: [ 0.00782462]
# Error of the epoch 399: [ 0.00782462]
# Error of the epoch 400: [ 0.00782462]
# Error of the epoch 401: [ 0.00782462]
# Error of the epoch 402: [ 0.00782462]
# Error of the epoch 403: [ 0.00782462]
# Error of the epoch 404: [ 0.00782462]
# Error of the epoch 405: [ 0.00782462]
# Error of the epoch 406: [ 0.00782462]
# Error of the epoch 407: [ 0.00782462]
# Error of the epoch 408: [ 0.00782462]
# Error of the epoch 409: [ 0.00782462]
# Error of the epoch 410: [ 0.00782462]
# Error of the epoch 411: [ 0.00782462]
# Error of the epoch 412: [ 0.00782462]
# Error of the epoch 413: [ 0.00782462]
# Error of the epoch 414: [ 0.00782462]
# Error of the epoch 415: [ 0.00782462]
# Error of the epoch 416: [ 0.00782462]
# Error of the epoch 417: [ 0.00782462]
# Error of the epoch 418: [ 0.00782462]
# Error of the epoch 419: [ 0.00782462]
# Error of the epoch 420: [ 0.00782462]
# Error of the epoch 421: [ 0.00782462]
# Error of the epoch 422: [ 0.00782462]
# Error of the epoch 423: [ 0.00782462]
# Error of the epoch 424: [ 0.00782462]
# Error of the epoch 425: [ 0.00782462]
# Error of the epoch 426: [ 0.00782462]
# Error of the epoch 427: [ 0.00782462]
# Error of the epoch 428: [ 0.00782462]
# Error of the epoch 429: [ 0.00782462]
# Error of the epoch 430: [ 0.00782462]
# Error of the epoch 431: [ 0.00782462]
# Error of the epoch 432: [ 0.00782462]
# Error of the epoch 433: [ 0.00782462]
# Error of the epoch 434: [ 0.00782462]
# Error of the epoch 435: [ 0.00782462]
# Error of the epoch 436: [ 0.00782462]
# Error of the epoch 437: [ 0.00782462]
# Error of the epoch 438: [ 0.00782462]
# Error of the epoch 439: [ 0.00782462]
# Error of the epoch 440: [ 0.00782462]
# Error of the epoch 441: [ 0.00782462]
# Error of the epoch 442: [ 0.00782462]
# Error of the epoch 443: [ 0.00782462]
# Error of the epoch 444: [ 0.00782462]
# Error of the epoch 445: [ 0.00782462]
# Error of the epoch 446: [ 0.00782462]
# Error of the epoch 447: [ 0.00782462]
# Error of the epoch 448: [ 0.00782462]
# Error of the epoch 449: [ 0.00782462]
# Error of the epoch 450: [ 0.00782462]
# Error of the epoch 451: [ 0.00782462]
# Error of the epoch 452: [ 0.00782462]
# Error of the epoch 453: [ 0.00782462]
# Error of the epoch 454: [ 0.00782462]
# Error of the epoch 455: [ 0.00782462]
# Error of the epoch 456: [ 0.00782462]
# Error of the epoch 457: [ 0.00782462]
# Error of the epoch 458: [ 0.00782462]
# Error of the epoch 459: [ 0.00782462]
# Error of the epoch 460: [ 0.00782462]
# Error of the epoch 461: [ 0.00782462]
# Error of the epoch 462: [ 0.00782462]
# Error of the epoch 463: [ 0.00782462]
# Error of the epoch 464: [ 0.00782462]
# Error of the epoch 465: [ 0.00782462]
# Error of the epoch 466: [ 0.00782462]
# Error of the epoch 467: [ 0.00782462]
# Error of the epoch 468: [ 0.00782462]
# Error of the epoch 469: [ 0.00782462]
# Error of the epoch 470: [ 0.00782462]
# Error of the epoch 471: [ 0.00782462]
# Error of the epoch 472: [ 0.00782462]
# Error of the epoch 473: [ 0.00782462]
# Error of the epoch 474: [ 0.00782462]
# Error of the epoch 475: [ 0.00782462]
# Error of the epoch 476: [ 0.00782462]
# Error of the epoch 477: [ 0.00782462]
# Error of the epoch 478: [ 0.00782462]
# Error of the epoch 479: [ 0.00782462]
# Error of the epoch 480: [ 0.00782462]
# Error of the epoch 481: [ 0.00782462]
# Error of the epoch 482: [ 0.00782462]
# Error of the epoch 483: [ 0.00782462]
# Error of the epoch 484: [ 0.00782462]
# Error of the epoch 485: [ 0.00782462]
# Error of the epoch 486: [ 0.00782462]
# Error of the epoch 487: [ 0.00782462]
# Error of the epoch 488: [ 0.00782462]
# Error of the epoch 489: [ 0.00782462]
# Error of the epoch 490: [ 0.00782462]
# Error of the epoch 491: [ 0.00782462]
# Error of the epoch 492: [ 0.00782462]
# Error of the epoch 493: [ 0.00782462]
# Error of the epoch 494: [ 0.00782462]
# Error of the epoch 495: [ 0.00782462]
# Error of the epoch 496: [ 0.00782462]
# Error of the epoch 497: [ 0.00782462]
# Error of the epoch 498: [ 0.00782462]
# Error of the epoch 499: [ 0.00782462]
# Error of the epoch 500: [ 0.00782462]
# Error of the epoch 501: [ 0.00782462]
# Error of the epoch 502: [ 0.00782462]
# Error of the epoch 503: [ 0.00782462]
# Error of the epoch 504: [ 0.00782462]
# Error of the epoch 505: [ 0.00782462]
# Error of the epoch 506: [ 0.00782462]
# Error of the epoch 507: [ 0.00782462]
# Error of the epoch 508: [ 0.00782462]
# Error of the epoch 509: [ 0.00782462]
# Error of the epoch 510: [ 0.00782462]
# Error of the epoch 511: [ 0.00782462]
# Error of the epoch 512: [ 0.00782462]
# Error of the epoch 513: [ 0.00782462]
# Error of the epoch 514: [ 0.00782462]
# Error of the epoch 515: [ 0.00782462]
# Error of the epoch 516: [ 0.00782462]
# Error of the epoch 517: [ 0.00782462]
# Error of the epoch 518: [ 0.00782462]
# Error of the epoch 519: [ 0.00782462]
# Error of the epoch 520: [ 0.00782462]
# Error of the epoch 521: [ 0.00782462]
# Error of the epoch 522: [ 0.00782462]
# Error of the epoch 523: [ 0.00782462]
# Error of the epoch 524: [ 0.00782462]
# Error of the epoch 525: [ 0.00782462]
# Error of the epoch 526: [ 0.00782462]
# Error of the epoch 527: [ 0.00782462]
# Error of the epoch 528: [ 0.00782462]
# Error of the epoch 529: [ 0.00782462]
# Error of the epoch 530: [ 0.00782462]
# Error of the epoch 531: [ 0.00782462]
# Error of the epoch 532: [ 0.00782462]
# Error of the epoch 533: [ 0.00782462]
# Error of the epoch 534: [ 0.00782462]
# Error of the epoch 535: [ 0.00782462]
# Error of the epoch 536: [ 0.00782462]
# Error of the epoch 537: [ 0.00782462]
# Error of the epoch 538: [ 0.00782462]
# Error of the epoch 539: [ 0.00782462]
# Error of the epoch 540: [ 0.00782462]
# Error of the epoch 541: [ 0.00782462]
# Error of the epoch 542: [ 0.00782462]
# Error of the epoch 543: [ 0.00782462]
# Error of the epoch 544: [ 0.00782462]
# Error of the epoch 545: [ 0.00782462]
# Error of the epoch 546: [ 0.00782462]
# Error of the epoch 547: [ 0.00782462]
# Error of the epoch 548: [ 0.00782462]
# Error of the epoch 549: [ 0.00782462]
# Error of the epoch 550: [ 0.00782462]
# Error of the epoch 551: [ 0.00782462]
# Error of the epoch 552: [ 0.00782462]
# Error of the epoch 553: [ 0.00782462]
# Error of the epoch 554: [ 0.00782462]
# Error of the epoch 555: [ 0.00782462]
# Error of the epoch 556: [ 0.00782462]
# Error of the epoch 557: [ 0.00782462]
# Error of the epoch 558: [ 0.00782462]
# Error of the epoch 559: [ 0.00782462]
# Error of the epoch 560: [ 0.00782462]
# Error of the epoch 561: [ 0.00782462]
# Error of the epoch 562: [ 0.00782462]
# Error of the epoch 563: [ 0.00782462]
# Error of the epoch 564: [ 0.00782462]
# Error of the epoch 565: [ 0.00782462]
# Error of the epoch 566: [ 0.00782462]
# Error of the epoch 567: [ 0.00782462]
# Error of the epoch 568: [ 0.00782462]
# Error of the epoch 569: [ 0.00782462]
# Error of the epoch 570: [ 0.00782462]
# Error of the epoch 571: [ 0.00782462]
# Error of the epoch 572: [ 0.00782462]
# Error of the epoch 573: [ 0.00782462]
# Error of the epoch 574: [ 0.00782462]
# Error of the epoch 575: [ 0.00782462]
# Error of the epoch 576: [ 0.00782462]
# Error of the epoch 577: [ 0.00782462]
# Error of the epoch 578: [ 0.00782462]
# Error of the epoch 579: [ 0.00782462]
# Error of the epoch 580: [ 0.00782462]
# Error of the epoch 581: [ 0.00782462]
# Error of the epoch 582: [ 0.00782462]
# Error of the epoch 583: [ 0.00782462]
# Error of the epoch 584: [ 0.00782462]
# Error of the epoch 585: [ 0.00782462]
# Error of the epoch 586: [ 0.00782462]
# Error of the epoch 587: [ 0.00782462]
# Error of the epoch 588: [ 0.00782462]
# Error of the epoch 589: [ 0.00782462]
# Error of the epoch 590: [ 0.00782462]
# Error of the epoch 591: [ 0.00782462]
# Error of the epoch 592: [ 0.00782462]
# Error of the epoch 593: [ 0.00782462]
# Error of the epoch 594: [ 0.00782462]
# Error of the epoch 595: [ 0.00782462]
# Error of the epoch 596: [ 0.00782462]
# Error of the epoch 597: [ 0.00782462]
# Error of the epoch 598: [ 0.00782462]
# Error of the epoch 599: [ 0.00782462]
# Error of the epoch 600: [ 0.00782462]
# Error of the epoch 601: [ 0.00782462]
# Error of the epoch 602: [ 0.00782462]
# Error of the epoch 603: [ 0.00782462]
# Error of the epoch 604: [ 0.00782462]
# Error of the epoch 605: [ 0.00782462]
# Error of the epoch 606: [ 0.00782462]
# Error of the epoch 607: [ 0.00782462]
# Error of the epoch 608: [ 0.00782462]
# Error of the epoch 609: [ 0.00782462]
# Error of the epoch 610: [ 0.00782462]
# Error of the epoch 611: [ 0.00782462]
# Error of the epoch 612: [ 0.00782462]
# Error of the epoch 613: [ 0.00782462]
# Error of the epoch 614: [ 0.00782462]
# Error of the epoch 615: [ 0.00782462]
# Error of the epoch 616: [ 0.00782462]
# Error of the epoch 617: [ 0.00782462]
# Error of the epoch 618: [ 0.00782462]
# Error of the epoch 619: [ 0.00782462]
# Error of the epoch 620: [ 0.00782462]
# Error of the epoch 621: [ 0.00782462]
# Error of the epoch 622: [ 0.00782462]
# Error of the epoch 623: [ 0.00782462]
# Error of the epoch 624: [ 0.00782462]
# Error of the epoch 625: [ 0.00782462]
# Error of the epoch 626: [ 0.00782462]
# Error of the epoch 627: [ 0.00782462]
# Error of the epoch 628: [ 0.00782462]
# Error of the epoch 629: [ 0.00782462]
# Error of the epoch 630: [ 0.00782462]
# Error of the epoch 631: [ 0.00782462]
# Error of the epoch 632: [ 0.00782462]
# Error of the epoch 633: [ 0.00782462]
# Error of the epoch 634: [ 0.00782462]
# Error of the epoch 635: [ 0.00782462]
# Error of the epoch 636: [ 0.00782462]
# Error of the epoch 637: [ 0.00782462]
# Error of the epoch 638: [ 0.00782462]
# Error of the epoch 639: [ 0.00782462]
# Error of the epoch 640: [ 0.00782462]
# Error of the epoch 641: [ 0.00782462]
# Error of the epoch 642: [ 0.00782462]
# Error of the epoch 643: [ 0.00782462]
# Error of the epoch 644: [ 0.00782462]
# Error of the epoch 645: [ 0.00782462]
# Error of the epoch 646: [ 0.00782462]
# Error of the epoch 647: [ 0.00782462]
# Error of the epoch 648: [ 0.00782462]
# Error of the epoch 649: [ 0.00782462]
# Error of the epoch 650: [ 0.00782462]
# Error of the epoch 651: [ 0.00782462]
# Error of the epoch 652: [ 0.00782462]
# Error of the epoch 653: [ 0.00782462]
# Error of the epoch 654: [ 0.00782462]
# Error of the epoch 655: [ 0.00782462]
# Error of the epoch 656: [ 0.00782462]
# Error of the epoch 657: [ 0.00782462]
# Error of the epoch 658: [ 0.00782462]
# Error of the epoch 659: [ 0.00782462]
# Error of the epoch 660: [ 0.00782462]
# Error of the epoch 661: [ 0.00782462]
# Error of the epoch 662: [ 0.00782462]
# Error of the epoch 663: [ 0.00782462]
# Error of the epoch 664: [ 0.00782462]
# Error of the epoch 665: [ 0.00782462]
# Error of the epoch 666: [ 0.00782462]
# Error of the epoch 667: [ 0.00782462]
# Error of the epoch 668: [ 0.00782462]
# Error of the epoch 669: [ 0.00782462]
# Error of the epoch 670: [ 0.00782462]
# Error of the epoch 671: [ 0.00782462]
# Error of the epoch 672: [ 0.00782462]
# Error of the epoch 673: [ 0.00782462]
# Error of the epoch 674: [ 0.00782462]
# Error of the epoch 675: [ 0.00782462]
# Error of the epoch 676: [ 0.00782462]
# Error of the epoch 677: [ 0.00782462]
# Error of the epoch 678: [ 0.00782462]
# Error of the epoch 679: [ 0.00782462]
# Error of the epoch 680: [ 0.00782462]
# Error of the epoch 681: [ 0.00782462]
# Error of the epoch 682: [ 0.00782462]
# Error of the epoch 683: [ 0.00782462]
# Error of the epoch 684: [ 0.00782462]
# Error of the epoch 685: [ 0.00782462]
# Error of the epoch 686: [ 0.00782462]
# Error of the epoch 687: [ 0.00782462]
# Error of the epoch 688: [ 0.00782462]
# Error of the epoch 689: [ 0.00782462]
# Error of the epoch 690: [ 0.00782462]
# Error of the epoch 691: [ 0.00782462]
# Error of the epoch 692: [ 0.00782462]
# Error of the epoch 693: [ 0.00782462]
# Error of the epoch 694: [ 0.00782462]
# Error of the epoch 695: [ 0.00782462]
# Error of the epoch 696: [ 0.00782462]
# Error of the epoch 697: [ 0.00782462]
# Error of the epoch 698: [ 0.00782462]
# Error of the epoch 699: [ 0.00782462]
# Error of the epoch 700: [ 0.00782462]
# Error of the epoch 701: [ 0.00782462]
# Error of the epoch 702: [ 0.00782462]
# Error of the epoch 703: [ 0.00782462]
# Error of the epoch 704: [ 0.00782462]
# Error of the epoch 705: [ 0.00782462]
# Error of the epoch 706: [ 0.00782462]
# Error of the epoch 707: [ 0.00782462]
# Error of the epoch 708: [ 0.00782462]
# Error of the epoch 709: [ 0.00782462]
# Error of the epoch 710: [ 0.00782462]
# Error of the epoch 711: [ 0.00782462]
# Error of the epoch 712: [ 0.00782462]
# Error of the epoch 713: [ 0.00782462]
# Error of the epoch 714: [ 0.00782462]
# Error of the epoch 715: [ 0.00782462]
# Error of the epoch 716: [ 0.00782462]
# Error of the epoch 717: [ 0.00782462]
# Error of the epoch 718: [ 0.00782462]
# Error of the epoch 719: [ 0.00782462]
# Error of the epoch 720: [ 0.00782462]
# Error of the epoch 721: [ 0.00782462]
# Error of the epoch 722: [ 0.00782462]
# Error of the epoch 723: [ 0.00782462]
# Error of the epoch 724: [ 0.00782462]
# Error of the epoch 725: [ 0.00782462]
# Error of the epoch 726: [ 0.00782462]
# Error of the epoch 727: [ 0.00782462]
# Error of the epoch 728: [ 0.00782462]
# Error of the epoch 729: [ 0.00782462]
# Error of the epoch 730: [ 0.00782462]
# Error of the epoch 731: [ 0.00782462]
# Error of the epoch 732: [ 0.00782462]
# Error of the epoch 733: [ 0.00782462]
# Error of the epoch 734: [ 0.00782462]
# Error of the epoch 735: [ 0.00782462]
# Error of the epoch 736: [ 0.00782462]
# Error of the epoch 737: [ 0.00782462]
# Error of the epoch 738: [ 0.00782462]
# Error of the epoch 739: [ 0.00782462]
# Error of the epoch 740: [ 0.00782462]
# Error of the epoch 741: [ 0.00782462]
# Error of the epoch 742: [ 0.00782462]
# Error of the epoch 743: [ 0.00782462]
# Error of the epoch 744: [ 0.00782462]
# Error of the epoch 745: [ 0.00782462]
# Error of the epoch 746: [ 0.00782462]
# Error of the epoch 747: [ 0.00782462]
# Error of the epoch 748: [ 0.00782462]
# Error of the epoch 749: [ 0.00782462]
# Error of the epoch 750: [ 0.00782462]
# Error of the epoch 751: [ 0.00782462]
# Error of the epoch 752: [ 0.00782462]
# Error of the epoch 753: [ 0.00782462]
# Error of the epoch 754: [ 0.00782462]
# Error of the epoch 755: [ 0.00782462]
# Error of the epoch 756: [ 0.00782462]
# Error of the epoch 757: [ 0.00782462]
# Error of the epoch 758: [ 0.00782462]
# Error of the epoch 759: [ 0.00782462]
# Error of the epoch 760: [ 0.00782462]
# Error of the epoch 761: [ 0.00782462]
# Error of the epoch 762: [ 0.00782462]
# Error of the epoch 763: [ 0.00782462]
# Error of the epoch 764: [ 0.00782462]
# Error of the epoch 765: [ 0.00782462]
# Error of the epoch 766: [ 0.00782462]
# Error of the epoch 767: [ 0.00782462]
# Error of the epoch 768: [ 0.00782462]
# Error of the epoch 769: [ 0.00782462]
# Error of the epoch 770: [ 0.00782462]
# Error of the epoch 771: [ 0.00782462]
# Error of the epoch 772: [ 0.00782462]
# Error of the epoch 773: [ 0.00782462]
# Error of the epoch 774: [ 0.00782462]
# Error of the epoch 775: [ 0.00782462]
# Error of the epoch 776: [ 0.00782462]
# Error of the epoch 777: [ 0.00782462]
# Error of the epoch 778: [ 0.00782462]
# Error of the epoch 779: [ 0.00782462]
# Error of the epoch 780: [ 0.00782462]
# Error of the epoch 781: [ 0.00782462]
# Error of the epoch 782: [ 0.00782462]
# Error of the epoch 783: [ 0.00782462]
# Error of the epoch 784: [ 0.00782462]
# Error of the epoch 785: [ 0.00782462]
# Error of the epoch 786: [ 0.00782462]
# Error of the epoch 787: [ 0.00782462]
# Error of the epoch 788: [ 0.00782462]
# Error of the epoch 789: [ 0.00782462]
# Error of the epoch 790: [ 0.00782462]
# Error of the epoch 791: [ 0.00782462]
# Error of the epoch 792: [ 0.00782462]
# Error of the epoch 793: [ 0.00782462]
# Error of the epoch 794: [ 0.00782462]
# Error of the epoch 795: [ 0.00782462]
# Error of the epoch 796: [ 0.00782462]
# Error of the epoch 797: [ 0.00782462]
# Error of the epoch 798: [ 0.00782462]
# Error of the epoch 799: [ 0.00782462]
# Error of the epoch 800: [ 0.00782462]
# Error of the epoch 801: [ 0.00782462]
# Error of the epoch 802: [ 0.00782462]
# Error of the epoch 803: [ 0.00782462]
# Error of the epoch 804: [ 0.00782462]
# Error of the epoch 805: [ 0.00782462]
# Error of the epoch 806: [ 0.00782462]
# Error of the epoch 807: [ 0.00782462]
# Error of the epoch 808: [ 0.00782462]
# Error of the epoch 809: [ 0.00782462]
# Error of the epoch 810: [ 0.00782462]
# Error of the epoch 811: [ 0.00782462]
# Error of the epoch 812: [ 0.00782462]
# Error of the epoch 813: [ 0.00782462]
# Error of the epoch 814: [ 0.00782462]
# Error of the epoch 815: [ 0.00782462]
# Error of the epoch 816: [ 0.00782462]
# Error of the epoch 817: [ 0.00782462]
# Error of the epoch 818: [ 0.00782462]
# Error of the epoch 819: [ 0.00782462]
# Error of the epoch 820: [ 0.00782462]
# Error of the epoch 821: [ 0.00782462]
# Error of the epoch 822: [ 0.00782462]
# Error of the epoch 823: [ 0.00782462]
# Error of the epoch 824: [ 0.00782462]
# Error of the epoch 825: [ 0.00782462]
# Error of the epoch 826: [ 0.00782462]
# Error of the epoch 827: [ 0.00782462]
# Error of the epoch 828: [ 0.00782462]
# Error of the epoch 829: [ 0.00782462]
# Error of the epoch 830: [ 0.00782462]
# Error of the epoch 831: [ 0.00782462]
# Error of the epoch 832: [ 0.00782462]
# Error of the epoch 833: [ 0.00782462]
# Error of the epoch 834: [ 0.00782462]
# Error of the epoch 835: [ 0.00782462]
# Error of the epoch 836: [ 0.00782462]
# Error of the epoch 837: [ 0.00782462]
# Error of the epoch 838: [ 0.00782462]
# Error of the epoch 839: [ 0.00782462]
# Error of the epoch 840: [ 0.00782462]
# Error of the epoch 841: [ 0.00782462]
# Error of the epoch 842: [ 0.00782462]
# Error of the epoch 843: [ 0.00782462]
# Error of the epoch 844: [ 0.00782462]
# Error of the epoch 845: [ 0.00782462]
# Error of the epoch 846: [ 0.00782462]
# Error of the epoch 847: [ 0.00782462]
# Error of the epoch 848: [ 0.00782462]
# Error of the epoch 849: [ 0.00782462]
# Error of the epoch 850: [ 0.00782462]
# Error of the epoch 851: [ 0.00782462]
# Error of the epoch 852: [ 0.00782462]
# Error of the epoch 853: [ 0.00782462]
# Error of the epoch 854: [ 0.00782462]
# Error of the epoch 855: [ 0.00782462]
# Error of the epoch 856: [ 0.00782462]
# Error of the epoch 857: [ 0.00782462]
# Error of the epoch 858: [ 0.00782462]
# Error of the epoch 859: [ 0.00782462]
# Error of the epoch 860: [ 0.00782462]
# Error of the epoch 861: [ 0.00782462]
# Error of the epoch 862: [ 0.00782462]
# Error of the epoch 863: [ 0.00782462]
# Error of the epoch 864: [ 0.00782462]
# Error of the epoch 865: [ 0.00782462]
# Error of the epoch 866: [ 0.00782462]
# Error of the epoch 867: [ 0.00782462]
# Error of the epoch 868: [ 0.00782462]
# Error of the epoch 869: [ 0.00782462]
# Error of the epoch 870: [ 0.00782462]
# Error of the epoch 871: [ 0.00782462]
# Error of the epoch 872: [ 0.00782462]
# Error of the epoch 873: [ 0.00782462]
# Error of the epoch 874: [ 0.00782462]
# Error of the epoch 875: [ 0.00782462]
# Error of the epoch 876: [ 0.00782462]
# Error of the epoch 877: [ 0.00782462]
# Error of the epoch 878: [ 0.00782462]
# Error of the epoch 879: [ 0.00782462]
# Error of the epoch 880: [ 0.00782462]
# Error of the epoch 881: [ 0.00782462]
# Error of the epoch 882: [ 0.00782462]
# Error of the epoch 883: [ 0.00782462]
# Error of the epoch 884: [ 0.00782462]
# Error of the epoch 885: [ 0.00782462]
# Error of the epoch 886: [ 0.00782462]
# Error of the epoch 887: [ 0.00782462]
# Error of the epoch 888: [ 0.00782462]
# Error of the epoch 889: [ 0.00782462]
# Error of the epoch 890: [ 0.00782462]
# Error of the epoch 891: [ 0.00782462]
# Error of the epoch 892: [ 0.00782462]
# Error of the epoch 893: [ 0.00782462]
# Error of the epoch 894: [ 0.00782462]
# Error of the epoch 895: [ 0.00782462]
# Error of the epoch 896: [ 0.00782462]
# Error of the epoch 897: [ 0.00782462]
# Error of the epoch 898: [ 0.00782462]
# Error of the epoch 899: [ 0.00782462]
# Error of the epoch 900: [ 0.00782462]
# Error of the epoch 901: [ 0.00782462]
# Error of the epoch 902: [ 0.00782462]
# Error of the epoch 903: [ 0.00782462]
# Error of the epoch 904: [ 0.00782462]
# Error of the epoch 905: [ 0.00782462]
# Error of the epoch 906: [ 0.00782462]
# Error of the epoch 907: [ 0.00782462]
# Error of the epoch 908: [ 0.00782462]
# Error of the epoch 909: [ 0.00782462]
# Error of the epoch 910: [ 0.00782462]
# Error of the epoch 911: [ 0.00782462]
# Error of the epoch 912: [ 0.00782462]
# Error of the epoch 913: [ 0.00782462]
# Error of the epoch 914: [ 0.00782462]
# Error of the epoch 915: [ 0.00782462]
# Error of the epoch 916: [ 0.00782462]
# Error of the epoch 917: [ 0.00782462]
# Error of the epoch 918: [ 0.00782462]
# Error of the epoch 919: [ 0.00782462]
# Error of the epoch 920: [ 0.00782462]
# Error of the epoch 921: [ 0.00782462]
# Error of the epoch 922: [ 0.00782462]
# Error of the epoch 923: [ 0.00782462]
# Error of the epoch 924: [ 0.00782462]
# Error of the epoch 925: [ 0.00782462]
# Error of the epoch 926: [ 0.00782462]
# Error of the epoch 927: [ 0.00782462]
# Error of the epoch 928: [ 0.00782462]
# Error of the epoch 929: [ 0.00782462]
# Error of the epoch 930: [ 0.00782462]
# Error of the epoch 931: [ 0.00782462]
# Error of the epoch 932: [ 0.00782462]
# Error of the epoch 933: [ 0.00782462]
# Error of the epoch 934: [ 0.00782462]
# Error of the epoch 935: [ 0.00782462]
# Error of the epoch 936: [ 0.00782462]
# Error of the epoch 937: [ 0.00782462]
# Error of the epoch 938: [ 0.00782462]
# Error of the epoch 939: [ 0.00782462]
# Error of the epoch 940: [ 0.00782462]
# Error of the epoch 941: [ 0.00782462]
# Error of the epoch 942: [ 0.00782462]
# Error of the epoch 943: [ 0.00782462]
# Error of the epoch 944: [ 0.00782462]
# Error of the epoch 945: [ 0.00782462]
# Error of the epoch 946: [ 0.00782462]
# Error of the epoch 947: [ 0.00782462]
# Error of the epoch 948: [ 0.00782462]
# Error of the epoch 949: [ 0.00782462]
# Error of the epoch 950: [ 0.00782462]
# Error of the epoch 951: [ 0.00782462]
# Error of the epoch 952: [ 0.00782462]
# Error of the epoch 953: [ 0.00782462]
# Error of the epoch 954: [ 0.00782462]
# Error of the epoch 955: [ 0.00782462]
# Error of the epoch 956: [ 0.00782462]
# Error of the epoch 957: [ 0.00782462]
# Error of the epoch 958: [ 0.00782462]
# Error of the epoch 959: [ 0.00782462]
# Error of the epoch 960: [ 0.00782462]
# Error of the epoch 961: [ 0.00782462]
# Error of the epoch 962: [ 0.00782462]
# Error of the epoch 963: [ 0.00782462]
# Error of the epoch 964: [ 0.00782462]
# Error of the epoch 965: [ 0.00782462]
# Error of the epoch 966: [ 0.00782462]
# Error of the epoch 967: [ 0.00782462]
# Error of the epoch 968: [ 0.00782462]
# Error of the epoch 969: [ 0.00782462]
# Error of the epoch 970: [ 0.00782462]
# Error of the epoch 971: [ 0.00782462]
# Error of the epoch 972: [ 0.00782462]
# Error of the epoch 973: [ 0.00782462]
# Error of the epoch 974: [ 0.00782462]
# Error of the epoch 975: [ 0.00782462]
# Error of the epoch 976: [ 0.00782462]
# Error of the epoch 977: [ 0.00782462]
# Error of the epoch 978: [ 0.00782462]
# Error of the epoch 979: [ 0.00782462]
# Error of the epoch 980: [ 0.00782462]
# Error of the epoch 981: [ 0.00782462]
# Error of the epoch 982: [ 0.00782462]
# Error of the epoch 983: [ 0.00782462]
# Error of the epoch 984: [ 0.00782462]
# Error of the epoch 985: [ 0.00782462]
# Error of the epoch 986: [ 0.00782462]
# Error of the epoch 987: [ 0.00782462]
# Error of the epoch 988: [ 0.00782462]
# Error of the epoch 989: [ 0.00782462]
# Error of the epoch 990: [ 0.00782462]
# Error of the epoch 991: [ 0.00782462]
# Error of the epoch 992: [ 0.00782462]
# Error of the epoch 993: [ 0.00782462]
# Error of the epoch 994: [ 0.00782462]
# Error of the epoch 995: [ 0.00782462]
# Error of the epoch 996: [ 0.00782462]
# Error of the epoch 997: [ 0.00782462]
# Error of the epoch 998: [ 0.00782462]
# Error of the epoch 999: [ 0.00782462]
# Error of the epoch 1000: [ 0.00782462]
# Accuracy of our LLSR:98.4%

# %% [markdown]
# # Vectorized Version of Minibatch Gradient Descent
#
# Finally, we can do minibatch training, it is the same as batch training (the formula) but one iteration runs over a subset of the whole dataset at a time, and those subsets (minibatches) are shuffle before training. Note how I did that minibatch splitting and shuffling using our $numpy.random$

# %%
def train_minibatch(X_train, Y_train, batch_size=256, lr=0.1, lambdar=0.0001, epochs=50):
    
    n = X_train.shape[0]
    
    # Xavier Initialization
    np.random.seed(1234)
    w = np.random.randn(1, n) * (np.sqrt(2. / (n + 1)))
    b = 0

    for epoch in range(epochs):
        
        # Split into minibatches into a *list* of sub-arrays
        # we want to split along the number of instances, so axis = 1
        X_minibatch = np.array_split(X_train, batch_size, axis = 1)
        Y_minibatch = np.array_split(Y_train, batch_size, axis = 1) 
        
        # We shuffle the minibatches of X and Y in the same way
        nmb = len(X_minibatch) # number of minibatches
        np.random.seed(5678)
        shuffled_index = np.random.permutation(range(nmb))
                                               
        # Now we can do the training, we cannot vectorize over different minibatches
        # They are like our "epochs"
        for i in range(nmb):
            X_current = X_minibatch[shuffled_index[i]]
            Y_current = Y_minibatch[shuffled_index[i]]
            m = X_current.shape[1]

            # Forward pass
            z = np.dot(w, X_current) + b
            o = 1. / (1 + np.exp(-z))
            r = np.sum(w**2)    

            # Calculate the loss 
            # (axis here makes the training more general \
            # if there are more output neurons than 1, \
            # we want to sum over the instances, so axis=1)
            L = (np.sum((Y_current - o)**2, axis=1) + lambdar * r) / (2 * m)

            # Backward pass and update the weights/bias
            w -= lr * (np.dot((o - Y_current) * o * (1 - o), X_current.T) + lambdar * w) / m
            b -= lr * (np.sum((o - X_current) * o * (1 - o))) / m

            print("Error of the iteration {0}: {1}".format(epoch * nmb + i + 1, L))

    return w, b

# %% [markdown]
# Minibatch Training for this LLSR is very sensitive to hyperparameter choosing. Should use with early stopping. Do not supprise if the accurary is bad. Shuffling the minibatch also takes time, so do not run this with large number of epochs.

# %%
# Do not run this for more than 100 epochs!!!!!!!!!
w_minibatch, b_minibatch = train_minibatch(X_train, Y_train, batch_size=512, lr=0.001, lambdar=0.0001, epochs=30)
_ = test_vectorized(X_test, Y_test, w_minibatch, b_minibatch)
# Out:
# Error of the iteration 1: [ 0.22118434]
# Error of the iteration 2: [ 0.17976785]
# Error of the iteration 3: [ 0.15162387]
# Error of the iteration 4: [ 0.10830519]
# Error of the iteration 5: [ 0.12619761]
# Error of the iteration 6: [ 0.10483169]
# Error of the iteration 7: [ 0.12129733]
# Error of the iteration 8: [ 0.11583833]
# Error of the iteration 9: [ 0.11066155]
# Error of the iteration 10: [ 0.08975013]
# Error of the iteration 11: [ 0.08627784]
# Error of the iteration 12: [ 0.10876119]
# Error of the iteration 13: [ 0.09482069]
# Error of the iteration 14: [ 0.07664979]
# Error of the iteration 15: [ 0.0764334]
# Error of the iteration 16: [ 0.08133182]
# Error of the iteration 17: [ 0.05457713]
# Error of the iteration 18: [ 0.07773994]
# Error of the iteration 19: [ 0.06370022]
# Error of the iteration 20: [ 0.04356047]
# Error of the iteration 21: [ 0.05819477]
# Error of the iteration 22: [ 0.08877874]
# Error of the iteration 23: [ 0.08304654]
# Error of the iteration 24: [ 0.04926506]
# Error of the iteration 25: [ 0.08117902]
# Error of the iteration 26: [ 0.04676329]
# Error of the iteration 27: [ 0.03735566]
# Error of the iteration 28: [ 0.04588246]
# Error of the iteration 29: [ 0.05810389]
# Error of the iteration 30: [ 0.03930762]
# Error of the iteration 31: [ 0.0661895]
# Error of the iteration 32: [ 0.0726314]
# Error of the iteration 33: [ 0.03344685]
# Error of the iteration 34: [ 0.07137879]
# Error of the iteration 35: [ 0.06075335]
# Error of the iteration 36: [ 0.0468738]
# Error of the iteration 37: [ 0.03490932]
# Error of the iteration 38: [ 0.05532333]
# Error of the iteration 39: [ 0.04292108]
# Error of the iteration 40: [ 0.05941753]
# Error of the iteration 41: [ 0.02058644]
# Error of the iteration 42: [ 0.05167678]
# Error of the iteration 43: [ 0.05401554]
# Error of the iteration 44: [ 0.0464273]
# Error of the iteration 45: [ 0.05870668]
# Error of the iteration 46: [ 0.12556099]
# Error of the iteration 47: [ 0.07995532]
# Error of the iteration 48: [ 0.08480922]
# Error of the iteration 49: [ 0.12287437]
# Error of the iteration 50: [ 0.05424237]
# Error of the iteration 51: [ 0.04369366]
# Error of the iteration 52: [ 0.01902652]
# Error of the iteration 53: [ 0.07404456]
# Error of the iteration 54: [ 0.01865551]
# Error of the iteration 55: [ 0.08204266]
# Error of the iteration 56: [ 0.05761221]
# Error of the iteration 57: [ 0.0548101]
# Error of the iteration 58: [ 0.05579631]
# Error of the iteration 59: [ 0.08514886]
# Error of the iteration 60: [ 0.01982049]
# Error of the iteration 61: [ 0.04375972]
# Error of the iteration 62: [ 0.01719359]
# Error of the iteration 63: [ 0.01885714]
# Error of the iteration 64: [ 0.06339691]
# Error of the iteration 65: [ 0.01065694]
# Error of the iteration 66: [ 0.01386522]
# Error of the iteration 67: [ 0.08901786]
# Error of the iteration 68: [ 0.08062162]
# Error of the iteration 69: [ 0.05269606]
# Error of the iteration 70: [ 0.05523904]
# Error of the iteration 71: [ 0.04913255]
# Error of the iteration 72: [ 0.01879684]
# Error of the iteration 73: [ 0.10445271]
# Error of the iteration 74: [ 0.04827796]
# Error of the iteration 75: [ 0.01400753]
# Error of the iteration 76: [ 0.05452477]
# Error of the iteration 77: [ 0.05905899]
# Error of the iteration 78: [ 0.08299371]
# Error of the iteration 79: [ 0.01093896]
# Error of the iteration 80: [ 0.0855348]
# Error of the iteration 81: [ 0.01309465]
# Error of the iteration 82: [ 0.09102147]
# Error of the iteration 83: [ 0.05201785]
# Error of the iteration 84: [ 0.0159703]
# Error of the iteration 85: [ 0.05875434]
# Error of the iteration 86: [ 0.05623376]
# Error of the iteration 87: [ 0.0166705]
# Error of the iteration 88: [ 0.06122537]
# Error of the iteration 89: [ 0.03891116]
# Error of the iteration 90: [ 0.07561562]
# Error of the iteration 91: [ 0.00978612]
# Error of the iteration 92: [ 0.0109115]
# Error of the iteration 93: [ 0.03224195]
# Error of the iteration 94: [ 0.05607264]
# Error of the iteration 95: [ 0.04173125]
# Error of the iteration 96: [ 0.0506139]
# Error of the iteration 97: [ 0.01437297]
# Error of the iteration 98: [ 0.08933641]
# Error of the iteration 99: [ 0.01444544]
# Error of the iteration 100: [ 0.03636185]
# Error of the iteration 101: [ 0.06008517]
# Error of the iteration 102: [ 0.01013095]
# Error of the iteration 103: [ 0.01175218]
# Error of the iteration 104: [ 0.01357925]
# Error of the iteration 105: [ 0.10166835]
# Error of the iteration 106: [ 0.07985129]
# Error of the iteration 107: [ 0.03979166]
# Error of the iteration 108: [ 0.00771116]
# Error of the iteration 109: [ 0.0652661]
# Error of the iteration 110: [ 0.09453347]
# Error of the iteration 111: [ 0.01070879]
# Error of the iteration 112: [ 0.11179531]
# Error of the iteration 113: [ 0.1349379]
# Error of the iteration 114: [ 0.01111086]
# Error of the iteration 115: [ 0.01072837]
# Error of the iteration 116: [ 0.05081869]
# Error of the iteration 117: [ 0.04572682]
# Error of the iteration 118: [ 0.05631847]
# Error of the iteration 119: [ 0.01175978]
# Error of the iteration 120: [ 0.01133722]
# Error of the iteration 121: [ 0.04701937]
# Error of the iteration 122: [ 0.01075343]
# Error of the iteration 123: [ 0.03769985]
# Error of the iteration 124: [ 0.05527794]
# Error of the iteration 125: [ 0.00653441]
# Error of the iteration 126: [ 0.01119965]
# Error of the iteration 127: [ 0.03958791]
# Error of the iteration 128: [ 0.00612224]
# Error of the iteration 129: [ 0.00858723]
# Error of the iteration 130: [ 0.01182733]
# Error of the iteration 131: [ 0.05986338]
# Error of the iteration 132: [ 0.04482802]
# Error of the iteration 133: [ 0.08280887]
# Error of the iteration 134: [ 0.00989453]
# Error of the iteration 135: [ 0.06176388]
# Error of the iteration 136: [ 0.04563988]
# Error of the iteration 137: [ 0.06449245]
# Error of the iteration 138: [ 0.0539086]
# Error of the iteration 139: [ 0.05503835]
# Error of the iteration 140: [ 0.05658795]
# Error of the iteration 141: [ 0.04723188]
# Error of the iteration 142: [ 0.05396337]
# Error of the iteration 143: [ 0.0906323]
# Error of the iteration 144: [ 0.04077638]
# Error of the iteration 145: [ 0.0085534]
# Error of the iteration 146: [ 0.00692396]
# Error of the iteration 147: [ 0.01300984]
# Error of the iteration 148: [ 0.04715307]
# Error of the iteration 149: [ 0.00969387]
# Error of the iteration 150: [ 0.09908241]
# Error of the iteration 151: [ 0.08296497]
# Error of the iteration 152: [ 0.04342656]
# Error of the iteration 153: [ 0.01049393]
# Error of the iteration 154: [ 0.00850388]
# Error of the iteration 155: [ 0.00939053]
# Error of the iteration 156: [ 0.01119392]
# Error of the iteration 157: [ 0.04902297]
# Error of the iteration 158: [ 0.04314726]
# Error of the iteration 159: [ 0.00772491]
# Error of the iteration 160: [ 0.04614824]
# Error of the iteration 161: [ 0.01175056]
# Error of the iteration 162: [ 0.00604075]
# Error of the iteration 163: [ 0.01007268]
# Error of the iteration 164: [ 0.03782299]
# Error of the iteration 165: [ 0.00804598]
# Error of the iteration 166: [ 0.00889317]
# Error of the iteration 167: [ 0.04139403]
# Error of the iteration 168: [ 0.00658573]
# Error of the iteration 169: [ 0.00983476]
# Error of the iteration 170: [ 0.01135691]
# Error of the iteration 171: [ 0.05519904]
# Error of the iteration 172: [ 0.04649682]
# Error of the iteration 173: [ 0.00994676]
# Error of the iteration 174: [ 0.0079387]
# Error of the iteration 175: [ 0.04843312]
# Error of the iteration 176: [ 0.00686526]
# Error of the iteration 177: [ 0.08715997]
# Error of the iteration 178: [ 0.04563182]
# Error of the iteration 179: [ 0.04798175]
# Error of the iteration 180: [ 0.04195482]
# Error of the iteration 181: [ 0.04431985]
# Error of the iteration 182: [ 0.04879319]
# Error of the iteration 183: [ 0.04576068]
# Error of the iteration 184: [ 0.04523145]
# Error of the iteration 185: [ 0.08833595]
# Error of the iteration 186: [ 0.05672671]
# Error of the iteration 187: [ 0.05438559]
# Error of the iteration 188: [ 0.08770966]
# Error of the iteration 189: [ 0.09448365]
# Error of the iteration 190: [ 0.05026063]
# Error of the iteration 191: [ 0.00778266]
# Error of the iteration 192: [ 0.00772924]
# Error of the iteration 193: [ 0.05121879]
# Error of the iteration 194: [ 0.00954885]
# Error of the iteration 195: [ 0.08211035]
# Error of the iteration 196: [ 0.0072424]
# Error of the iteration 197: [ 0.04329261]
# Error of the iteration 198: [ 0.05270344]
# Error of the iteration 199: [ 0.05578633]
# Error of the iteration 200: [ 0.00725444]
# Error of the iteration 201: [ 0.05551234]
# Error of the iteration 202: [ 0.08765413]
# Error of the iteration 203: [ 0.05354293]
# Error of the iteration 204: [ 0.00615909]
# Error of the iteration 205: [ 0.05141422]
# Error of the iteration 206: [ 0.04593661]
# Error of the iteration 207: [ 0.04803612]
# Error of the iteration 208: [ 0.00946423]
# Error of the iteration 209: [ 0.00928113]
# Error of the iteration 210: [ 0.0401522]
# Error of the iteration 211: [ 0.05313401]
# Error of the iteration 212: [ 0.04505035]
# Error of the iteration 213: [ 0.09891469]
# Error of the iteration 214: [ 0.08592254]
# Error of the iteration 215: [ 0.00719369]
# Error of the iteration 216: [ 0.01027099]
# Error of the iteration 217: [ 0.00804827]
# Error of the iteration 218: [ 0.00710745]
# Error of the iteration 219: [ 0.13314965]
# Error of the iteration 220: [ 0.05459392]
# Error of the iteration 221: [ 0.0091562]
# Error of the iteration 222: [ 0.05087105]
# Error of the iteration 223: [ 0.16718642]
# Error of the iteration 224: [ 0.05507482]
# Error of the iteration 225: [ 0.00809755]
# Error of the iteration 226: [ 0.04453618]
# Error of the iteration 227: [ 0.10272277]
# Error of the iteration 228: [ 0.00712908]
# Error of the iteration 229: [ 0.0094545]
# Error of the iteration 230: [ 0.05281024]
# Error of the iteration 231: [ 0.00902293]
# Error of the iteration 232: [ 0.00807087]
# Error of the iteration 233: [ 0.00584543]
# Error of the iteration 234: [ 0.00708031]
# Error of the iteration 235: [ 0.13230102]
# Error of the iteration 236: [ 0.07377614]
# Error of the iteration 237: [ 0.0538801]
# Error of the iteration 238: [ 0.04549771]
# Error of the iteration 239: [ 0.04735382]
# Error of the iteration 240: [ 0.00808166]
# Error of the iteration 241: [ 0.09044691]
# Error of the iteration 242: [ 0.00636764]
# Error of the iteration 243: [ 0.00972876]
# Error of the iteration 244: [ 0.05374383]
# Error of the iteration 245: [ 0.00603304]
# Error of the iteration 246: [ 0.06200961]
# Error of the iteration 247: [ 0.0107808]
# Error of the iteration 248: [ 0.05729028]
# Error of the iteration 249: [ 0.00892409]
# Error of the iteration 250: [ 0.04986766]
# Error of the iteration 251: [ 0.07843187]
# Error of the iteration 252: [ 0.04644923]
# Error of the iteration 253: [ 0.00901045]
# Error of the iteration 254: [ 0.00479094]
# Error of the iteration 255: [ 0.04700662]
# Error of the iteration 256: [ 0.00531491]
# Error of the iteration 257: [ 0.00946422]
# Error of the iteration 258: [ 0.04486539]
# Error of the iteration 259: [ 0.00754782]
# Error of the iteration 260: [ 0.00497608]
# Error of the iteration 261: [ 0.01032302]
# Error of the iteration 262: [ 0.00878772]
# Error of the iteration 263: [ 0.0073777]
# Error of the iteration 264: [ 0.04690151]
# Error of the iteration 265: [ 0.049081]
# Error of the iteration 266: [ 0.04922313]
# Error of the iteration 267: [ 0.00967667]
# Error of the iteration 268: [ 0.04784542]
# Error of the iteration 269: [ 0.09455774]
# Error of the iteration 270: [ 0.00867267]
# Error of the iteration 271: [ 0.08126796]
# Error of the iteration 272: [ 0.13734553]
# Error of the iteration 273: [ 0.14849954]
# Error of the iteration 274: [ 0.0568797]
# Error of the iteration 275: [ 0.08925207]
# Error of the iteration 276: [ 0.04934191]
# Error of the iteration 277: [ 0.05744831]
# Error of the iteration 278: [ 0.07513218]
# Error of the iteration 279: [ 0.0943458]
# Error of the iteration 280: [ 0.07589021]
# Error of the iteration 281: [ 0.01170611]
# Error of the iteration 282: [ 0.00624822]
# Error of the iteration 283: [ 0.0431768]
# Error of the iteration 284: [ 0.09026502]
# Error of the iteration 285: [ 0.00767683]
# Error of the iteration 286: [ 0.05258032]
# Error of the iteration 287: [ 0.05370191]
# Error of the iteration 288: [ 0.0056145]
# Error of the iteration 289: [ 0.00930926]
# Error of the iteration 290: [ 0.04858754]
# Error of the iteration 291: [ 0.00931031]
# Error of the iteration 292: [ 0.08769447]
# Error of the iteration 293: [ 0.05697581]
# Error of the iteration 294: [ 0.04700693]
# Error of the iteration 295: [ 0.16823263]
# Error of the iteration 296: [ 0.00893228]
# Error of the iteration 297: [ 0.06717578]
# Error of the iteration 298: [ 0.05100011]
# Error of the iteration 299: [ 0.00698382]
# Error of the iteration 300: [ 0.00719964]
# Error of the iteration 301: [ 0.00656954]
# Error of the iteration 302: [ 0.005544]
# Error of the iteration 303: [ 0.05552246]
# Error of the iteration 304: [ 0.04780775]
# Error of the iteration 305: [ 0.0552204]
# Error of the iteration 306: [ 0.12783418]
# Error of the iteration 307: [ 0.0038614]
# Error of the iteration 308: [ 0.00806281]
# Error of the iteration 309: [ 0.00856863]
# Error of the iteration 310: [ 0.01094365]
# Error of the iteration 311: [ 0.06097074]
# Error of the iteration 312: [ 0.0868643]
# Error of the iteration 313: [ 0.00695402]
# Error of the iteration 314: [ 0.0057104]
# Error of the iteration 315: [ 0.04799087]
# Error of the iteration 316: [ 0.05571836]
# Error of the iteration 317: [ 0.10331183]
# Error of the iteration 318: [ 0.04706852]
# Error of the iteration 319: [ 0.00690816]
# Error of the iteration 320: [ 0.0104592]
# Error of the iteration 321: [ 0.00594007]
# Error of the iteration 322: [ 0.00676227]
# Error of the iteration 323: [ 0.0108995]
# Error of the iteration 324: [ 0.00656666]
# Error of the iteration 325: [ 0.08566315]
# Error of the iteration 326: [ 0.00858475]
# Error of the iteration 327: [ 0.08176024]
# Error of the iteration 328: [ 0.00750652]
# Error of the iteration 329: [ 0.00834856]
# Error of the iteration 330: [ 0.00739246]
# Error of the iteration 331: [ 0.04825552]
# Error of the iteration 332: [ 0.00876012]
# Error of the iteration 333: [ 0.10094534]
# Error of the iteration 334: [ 0.08129204]
# Error of the iteration 335: [ 0.00760144]
# Error of the iteration 336: [ 0.00746081]
# Error of the iteration 337: [ 0.00757343]
# Error of the iteration 338: [ 0.00744151]
# Error of the iteration 339: [ 0.05415382]
# Error of the iteration 340: [ 0.00813008]
# Error of the iteration 341: [ 0.05407708]
# Error of the iteration 342: [ 0.00946832]
# Error of the iteration 343: [ 0.00715334]
# Error of the iteration 344: [ 0.00375884]
# Error of the iteration 345: [ 0.00898264]
# Error of the iteration 346: [ 0.0054678]
# Error of the iteration 347: [ 0.0500468]
# Error of the iteration 348: [ 0.0924743]
# Error of the iteration 349: [ 0.04852068]
# Error of the iteration 350: [ 0.04870815]
# Error of the iteration 351: [ 0.05075784]
# Error of the iteration 352: [ 0.00452319]
# Error of the iteration 353: [ 0.04525202]
# Error of the iteration 354: [ 0.08394154]
# Error of the iteration 355: [ 0.05283047]
# Error of the iteration 356: [ 0.00686397]
# Error of the iteration 357: [ 0.04259595]
# Error of the iteration 358: [ 0.14166286]
# Error of the iteration 359: [ 0.00674625]
# Error of the iteration 360: [ 0.05116494]
# Error of the iteration 361: [ 0.00811425]
# Error of the iteration 362: [ 0.00727337]
# Error of the iteration 363: [ 0.09336247]
# Error of the iteration 364: [ 0.00735399]
# Error of the iteration 365: [ 0.07648111]
# Error of the iteration 366: [ 0.08221399]
# Error of the iteration 367: [ 0.08714539]
# Error of the iteration 368: [ 0.00986947]
# Error of the iteration 369: [ 0.00900246]
# Error of the iteration 370: [ 0.04791795]
# Error of the iteration 371: [ 0.005925]
# Error of the iteration 372: [ 0.00557276]
# Error of the iteration 373: [ 0.00580174]
# Error of the iteration 374: [ 0.13396125]
# Error of the iteration 375: [ 0.0070439]
# Error of the iteration 376: [ 0.05045421]
# Error of the iteration 377: [ 0.00597702]
# Error of the iteration 378: [ 0.0942684]
# Error of the iteration 379: [ 0.00743219]
# Error of the iteration 380: [ 0.05577082]
# Error of the iteration 381: [ 0.00586123]
# Error of the iteration 382: [ 0.00969776]
# Error of the iteration 383: [ 0.0544308]
# Error of the iteration 384: [ 0.00804748]
# Error of the iteration 385: [ 0.05563066]
# Error of the iteration 386: [ 0.0481136]
# Error of the iteration 387: [ 0.01074909]
# Error of the iteration 388: [ 0.00846397]
# Error of the iteration 389: [ 0.08820326]
# Error of the iteration 390: [ 0.00480125]
# Error of the iteration 391: [ 0.04631553]
# Error of the iteration 392: [ 0.04816216]
# Error of the iteration 393: [ 0.00543756]
# Error of the iteration 394: [ 0.00654068]
# Error of the iteration 395: [ 0.06160098]
# Error of the iteration 396: [ 0.00842739]
# Error of the iteration 397: [ 0.0628305]
# Error of the iteration 398: [ 0.00855887]
# Error of the iteration 399: [ 0.03763382]
# Error of the iteration 400: [ 0.10274463]
# Error of the iteration 401: [ 0.00670002]
# Error of the iteration 402: [ 0.07649479]
# Error of the iteration 403: [ 0.04809076]
# Error of the iteration 404: [ 0.08311532]
# Error of the iteration 405: [ 0.00776015]
# Error of the iteration 406: [ 0.09898641]
# Error of the iteration 407: [ 0.00680842]
# Error of the iteration 408: [ 0.00916593]
# Error of the iteration 409: [ 0.11919907]
# Error of the iteration 410: [ 0.08410775]
# Error of the iteration 411: [ 0.00954671]
# Error of the iteration 412: [ 0.08936954]
# Error of the iteration 413: [ 0.10480656]
# Error of the iteration 414: [ 0.04806642]
# Error of the iteration 415: [ 0.08681188]
# Error of the iteration 416: [ 0.09147714]
# Error of the iteration 417: [ 0.04556575]
# Error of the iteration 418: [ 0.01057019]
# Error of the iteration 419: [ 0.00769715]
# Error of the iteration 420: [ 0.04472955]
# Error of the iteration 421: [ 0.00831197]
# Error of the iteration 422: [ 0.07904051]
# Error of the iteration 423: [ 0.04853921]
# Error of the iteration 424: [ 0.0519442]
# Error of the iteration 425: [ 0.01279702]
# Error of the iteration 426: [ 0.0079862]
# Error of the iteration 427: [ 0.01051136]
# Error of the iteration 428: [ 0.00721367]
# Error of the iteration 429: [ 0.0071985]
# Error of the iteration 430: [ 0.16268903]
# Error of the iteration 431: [ 0.05083754]
# Error of the iteration 432: [ 0.0075613]
# Error of the iteration 433: [ 0.00770056]
# Error of the iteration 434: [ 0.00480084]
# Error of the iteration 435: [ 0.00396835]
# Error of the iteration 436: [ 0.00906266]
# Error of the iteration 437: [ 0.00731277]
# Error of the iteration 438: [ 0.006898]
# Error of the iteration 439: [ 0.05019874]
# Error of the iteration 440: [ 0.00511492]
# Error of the iteration 441: [ 0.0063592]
# Error of the iteration 442: [ 0.04572264]
# Error of the iteration 443: [ 0.01033204]
# Error of the iteration 444: [ 0.1294782]
# Error of the iteration 445: [ 0.00561569]
# Error of the iteration 446: [ 0.00708365]
# Error of the iteration 447: [ 0.04330635]
# Error of the iteration 448: [ 0.09359084]
# Error of the iteration 449: [ 0.00450639]
# Error of the iteration 450: [ 0.08523696]
# Error of the iteration 451: [ 0.11817433]
# Error of the iteration 452: [ 0.00531536]
# Error of the iteration 453: [ 0.05229923]
# Error of the iteration 454: [ 0.00490739]
# Error of the iteration 455: [ 0.05220745]
# Error of the iteration 456: [ 0.04322106]
# Error of the iteration 457: [ 0.00710289]
# Error of the iteration 458: [ 0.10113262]
# Error of the iteration 459: [ 0.09317517]
# Error of the iteration 460: [ 0.00718159]
# Error of the iteration 461: [ 0.00709037]
# Error of the iteration 462: [ 0.08995349]
# Error of the iteration 463: [ 0.0080693]
# Error of the iteration 464: [ 0.00761544]
# Error of the iteration 465: [ 0.00771823]
# Error of the iteration 466: [ 0.05080746]
# Error of the iteration 467: [ 0.13665763]
# Error of the iteration 468: [ 0.0525834]
# Error of the iteration 469: [ 0.0088977]
# Error of the iteration 470: [ 0.00701483]
# Error of the iteration 471: [ 0.05802164]
# Error of the iteration 472: [ 0.05329641]
# Error of the iteration 473: [ 0.05162803]
# Error of the iteration 474: [ 0.05157988]
# Error of the iteration 475: [ 0.06188557]
# Error of the iteration 476: [ 0.04990905]
# Error of the iteration 477: [ 0.04996369]
# Error of the iteration 478: [ 0.00710557]
# Error of the iteration 479: [ 0.00687633]
# Error of the iteration 480: [ 0.00767802]
# Error of the iteration 481: [ 0.00564508]
# Error of the iteration 482: [ 0.00480218]
# Error of the iteration 483: [ 0.00735923]
# Error of the iteration 484: [ 0.00898075]
# Error of the iteration 485: [ 0.07843032]
# Error of the iteration 486: [ 0.0951847]
# Error of the iteration 487: [ 0.00695755]
# Error of the iteration 488: [ 0.04457694]
# Error of the iteration 489: [ 0.04634402]
# Error of the iteration 490: [ 0.00740016]
# Error of the iteration 491: [ 0.00783173]
# Error of the iteration 492: [ 0.00848438]
# Error of the iteration 493: [ 0.09421377]
# Error of the iteration 494: [ 0.00658486]
# Error of the iteration 495: [ 0.0807852]
# Error of the iteration 496: [ 0.00674933]
# Error of the iteration 497: [ 0.0041312]
# Error of the iteration 498: [ 0.04865453]
# Error of the iteration 499: [ 0.00768091]
# Error of the iteration 500: [ 0.04245852]
# Error of the iteration 501: [ 0.00578497]
# Error of the iteration 502: [ 0.00781501]
# Error of the iteration 503: [ 0.05182864]
# Error of the iteration 504: [ 0.05474676]
# Error of the iteration 505: [ 0.00636478]
# Error of the iteration 506: [ 0.00791036]
# Error of the iteration 507: [ 0.00715857]
# Error of the iteration 508: [ 0.07942089]
# Error of the iteration 509: [ 0.04768981]
# Error of the iteration 510: [ 0.08548461]
# Error of the iteration 511: [ 0.04880881]
# Error of the iteration 512: [ 0.04951807]
# Error of the iteration 513: [ 0.01413661]
# Error of the iteration 514: [ 0.05140279]
# Error of the iteration 515: [ 0.00688188]
# Error of the iteration 516: [ 0.08146023]
# Error of the iteration 517: [ 0.04884293]
# Error of the iteration 518: [ 0.09419446]
# Error of the iteration 519: [ 0.0078047]
# Error of the iteration 520: [ 0.21888873]
# Error of the iteration 521: [ 0.05351928]
# Error of the iteration 522: [ 0.00691167]
# Error of the iteration 523: [ 0.04950564]
# Error of the iteration 524: [ 0.01117091]
# Error of the iteration 525: [ 0.01107547]
# Error of the iteration 526: [ 0.00800475]
# Error of the iteration 527: [ 0.04957757]
# Error of the iteration 528: [ 0.12470226]
# Error of the iteration 529: [ 0.00613899]
# Error of the iteration 530: [ 0.01048663]
# Error of the iteration 531: [ 0.04708013]
# Error of the iteration 532: [ 0.00566056]
# Error of the iteration 533: [ 0.00903486]
# Error of the iteration 534: [ 0.10669546]
# Error of the iteration 535: [ 0.05713558]
# Error of the iteration 536: [ 0.04248188]
# Error of the iteration 537: [ 0.05730272]
# Error of the iteration 538: [ 0.00904359]
# Error of the iteration 539: [ 0.00720496]
# Error of the iteration 540: [ 0.04229497]
# Error of the iteration 541: [ 0.04421723]
# Error of the iteration 542: [ 0.00918604]
# Error of the iteration 543: [ 0.05311776]
# Error of the iteration 544: [ 0.05558002]
# Error of the iteration 545: [ 0.00793347]
# Error of the iteration 546: [ 0.05987098]
# Error of the iteration 547: [ 0.05277723]
# Error of the iteration 548: [ 0.04184232]
# Error of the iteration 549: [ 0.00931552]
# Error of the iteration 550: [ 0.05597094]
# Error of the iteration 551: [ 0.04322004]
# Error of the iteration 552: [ 0.04968432]
# Error of the iteration 553: [ 0.00619982]
# Error of the iteration 554: [ 0.05089897]
# Error of the iteration 555: [ 0.05023886]
# Error of the iteration 556: [ 0.04511851]
# Error of the iteration 557: [ 0.05748773]
# Error of the iteration 558: [ 0.15038553]
# Error of the iteration 559: [ 0.09195524]
# Error of the iteration 560: [ 0.08848793]
# Error of the iteration 561: [ 0.13630467]
# Error of the iteration 562: [ 0.05264056]
# Error of the iteration 563: [ 0.04391705]
# Error of the iteration 564: [ 0.00737085]
# Error of the iteration 565: [ 0.08140464]
# Error of the iteration 566: [ 0.00767471]
# Error of the iteration 567: [ 0.09265776]
# Error of the iteration 568: [ 0.05208355]
# Error of the iteration 569: [ 0.05150836]
# Error of the iteration 570: [ 0.05455465]
# Error of the iteration 571: [ 0.09377559]
# Error of the iteration 572: [ 0.00815439]
# Error of the iteration 573: [ 0.04224129]
# Error of the iteration 574: [ 0.00725394]
# Error of the iteration 575: [ 0.00809479]
# Error of the iteration 576: [ 0.05853002]
# Error of the iteration 577: [ 0.0044423]
# Error of the iteration 578: [ 0.00589186]
# Error of the iteration 579: [ 0.09469038]
# Error of the iteration 580: [ 0.08576207]
# Error of the iteration 581: [ 0.05319824]
# Error of the iteration 582: [ 0.05324506]
# Error of the iteration 583: [ 0.04774799]
# Error of the iteration 584: [ 0.00928929]
# Error of the iteration 585: [ 0.11092308]
# Error of the iteration 586: [ 0.04933133]
# Error of the iteration 587: [ 0.00663545]
# Error of the iteration 588: [ 0.05221726]
# Error of the iteration 589: [ 0.0557912]
# Error of the iteration 590: [ 0.08566774]
# Error of the iteration 591: [ 0.00538949]
# Error of the iteration 592: [ 0.09016432]
# Error of the iteration 593: [ 0.00649868]
# Error of the iteration 594: [ 0.09644892]
# Error of the iteration 595: [ 0.05064756]
# Error of the iteration 596: [ 0.00872618]
# Error of the iteration 597: [ 0.05509237]
# Error of the iteration 598: [ 0.05526517]
# Error of the iteration 599: [ 0.00897996]
# Error of the iteration 600: [ 0.06108713]
# Error of the iteration 601: [ 0.0401152]
# Error of the iteration 602: [ 0.08111913]
# Error of the iteration 603: [ 0.00530588]
# Error of the iteration 604: [ 0.00638113]
# Error of the iteration 605: [ 0.03288791]
# Error of the iteration 606: [ 0.05377471]
# Error of the iteration 607: [ 0.0408046]
# Error of the iteration 608: [ 0.050531]
# Error of the iteration 609: [ 0.00810301]
# Error of the iteration 610: [ 0.09283249]
# Error of the iteration 611: [ 0.00874205]
# Error of the iteration 612: [ 0.03471915]
# Error of the iteration 613: [ 0.05932689]
# Error of the iteration 614: [ 0.00584432]
# Error of the iteration 615: [ 0.00697764]
# Error of the iteration 616: [ 0.00812827]
# Error of the iteration 617: [ 0.10493962]
# Error of the iteration 618: [ 0.08254388]
# Error of the iteration 619: [ 0.03992708]
# Error of the iteration 620: [ 0.00481587]
# Error of the iteration 621: [ 0.0643957]
# Error of the iteration 622: [ 0.09637601]
# Error of the iteration 623: [ 0.00653923]
# Error of the iteration 624: [ 0.11456728]
# Error of the iteration 625: [ 0.1398153]
# Error of the iteration 626: [ 0.00721648]
# Error of the iteration 627: [ 0.00670883]
# Error of the iteration 628: [ 0.04984183]
# Error of the iteration 629: [ 0.0438887]
# Error of the iteration 630: [ 0.05406993]
# Error of the iteration 631: [ 0.00738153]
# Error of the iteration 632: [ 0.00737955]
# Error of the iteration 633: [ 0.04659664]
# Error of the iteration 634: [ 0.00717642]
# Error of the iteration 635: [ 0.03777292]
# Error of the iteration 636: [ 0.05420135]
# Error of the iteration 637: [ 0.00437558]
# Error of the iteration 638: [ 0.007646]
# Error of the iteration 639: [ 0.03815747]
# Error of the iteration 640: [ 0.00419238]
# Error of the iteration 641: [ 0.00591203]
# Error of the iteration 642: [ 0.00849556]
# Error of the iteration 643: [ 0.05960524]
# Error of the iteration 644: [ 0.04351978]
# Error of the iteration 645: [ 0.08387053]
# Error of the iteration 646: [ 0.00693527]
# Error of the iteration 647: [ 0.06189055]
# Error of the iteration 648: [ 0.04509288]
# Error of the iteration 649: [ 0.06196559]
# Error of the iteration 650: [ 0.05319908]
# Error of the iteration 651: [ 0.05440628]
# Error of the iteration 652: [ 0.05554636]
# Error of the iteration 653: [ 0.04686647]
# Error of the iteration 654: [ 0.05394587]
# Error of the iteration 655: [ 0.09201204]
# Error of the iteration 656: [ 0.03920806]
# Error of the iteration 657: [ 0.00605552]
# Error of the iteration 658: [ 0.00506599]
# Error of the iteration 659: [ 0.00925567]
# Error of the iteration 660: [ 0.04541883]
# Error of the iteration 661: [ 0.00712798]
# Error of the iteration 662: [ 0.10004786]
# Error of the iteration 663: [ 0.08281009]
# Error of the iteration 664: [ 0.04343206]
# Error of the iteration 665: [ 0.00794474]
# Error of the iteration 666: [ 0.00614965]
# Error of the iteration 667: [ 0.00699016]
# Error of the iteration 668: [ 0.00867346]
# Error of the iteration 669: [ 0.0479806]
# Error of the iteration 670: [ 0.04212176]
# Error of the iteration 671: [ 0.00593267]
# Error of the iteration 672: [ 0.04520154]
# Error of the iteration 673: [ 0.00878839]
# Error of the iteration 674: [ 0.00438357]
# Error of the iteration 675: [ 0.00745483]
# Error of the iteration 676: [ 0.03673169]
# Error of the iteration 677: [ 0.00618822]
# Error of the iteration 678: [ 0.00695506]
# Error of the iteration 679: [ 0.04061884]
# Error of the iteration 680: [ 0.00501075]
# Error of the iteration 681: [ 0.00767953]
# Error of the iteration 682: [ 0.00904396]
# Error of the iteration 683: [ 0.05509252]
# Error of the iteration 684: [ 0.04603114]
# Error of the iteration 685: [ 0.00775818]
# Error of the iteration 686: [ 0.00607952]
# Error of the iteration 687: [ 0.04708407]
# Error of the iteration 688: [ 0.00547526]
# Error of the iteration 689: [ 0.08654143]
# Error of the iteration 690: [ 0.04471418]
# Error of the iteration 691: [ 0.04676152]
# Error of the iteration 692: [ 0.04083981]
# Error of the iteration 693: [ 0.04352976]
# Error of the iteration 694: [ 0.04796178]
# Error of the iteration 695: [ 0.04487474]
# Error of the iteration 696: [ 0.04445309]
# Error of the iteration 697: [ 0.08797857]
# Error of the iteration 698: [ 0.0562591]
# Error of the iteration 699: [ 0.05420305]
# Error of the iteration 700: [ 0.08783304]
# Error of the iteration 701: [ 0.09412886]
# Error of the iteration 702: [ 0.04896194]
# Error of the iteration 703: [ 0.00612707]
# Error of the iteration 704: [ 0.0063103]
# Error of the iteration 705: [ 0.05021714]
# Error of the iteration 706: [ 0.00790685]
# Error of the iteration 707: [ 0.08040123]
# Error of the iteration 708: [ 0.00592483]
# Error of the iteration 709: [ 0.04189488]
# Error of the iteration 710: [ 0.05159605]
# Error of the iteration 711: [ 0.05520595]
# Error of the iteration 712: [ 0.00573034]
# Error of the iteration 713: [ 0.05444137]
# Error of the iteration 714: [ 0.08649]
# Error of the iteration 715: [ 0.05258515]
# Error of the iteration 716: [ 0.00518769]
# Error of the iteration 717: [ 0.05105063]
# Error of the iteration 718: [ 0.04430121]
# Error of the iteration 719: [ 0.04686322]
# Error of the iteration 720: [ 0.00773792]
# Error of the iteration 721: [ 0.00774718]
# Error of the iteration 722: [ 0.03825121]
# Error of the iteration 723: [ 0.05248011]
# Error of the iteration 724: [ 0.04357598]
# Error of the iteration 725: [ 0.09892708]
# Error of the iteration 726: [ 0.08625817]
# Error of the iteration 727: [ 0.00602559]
# Error of the iteration 728: [ 0.0090259]
# Error of the iteration 729: [ 0.00672718]
# Error of the iteration 730: [ 0.00602611]
# Error of the iteration 731: [ 0.13305988]
# Error of the iteration 732: [ 0.05389585]
# Error of the iteration 733: [ 0.00794821]
# Error of the iteration 734: [ 0.04967251]
# Error of the iteration 735: [ 0.16793606]
# Error of the iteration 736: [ 0.05491994]
# Error of the iteration 737: [ 0.00667596]
# Error of the iteration 738: [ 0.04218114]
# Error of the iteration 739: [ 0.10315685]
# Error of the iteration 740: [ 0.00600879]
# Error of the iteration 741: [ 0.0078172]
# Error of the iteration 742: [ 0.05175798]
# Error of the iteration 743: [ 0.00781573]
# Error of the iteration 744: [ 0.00699113]
# Error of the iteration 745: [ 0.0048961]
# Error of the iteration 746: [ 0.00601691]
# Error of the iteration 747: [ 0.13138216]
# Error of the iteration 748: [ 0.07264209]
# Error of the iteration 749: [ 0.05262068]
# Error of the iteration 750: [ 0.04357003]
# Error of the iteration 751: [ 0.04560996]
# Error of the iteration 752: [ 0.00665784]
# Error of the iteration 753: [ 0.08952825]
# Error of the iteration 754: [ 0.00557145]
# Error of the iteration 755: [ 0.00872803]
# Error of the iteration 756: [ 0.05356703]
# Error of the iteration 757: [ 0.0050358]
# Error of the iteration 758: [ 0.06129499]
# Error of the iteration 759: [ 0.00911343]
# Error of the iteration 760: [ 0.05638489]
# Error of the iteration 761: [ 0.00798764]
# Error of the iteration 762: [ 0.04891466]
# Error of the iteration 763: [ 0.07642706]
# Error of the iteration 764: [ 0.04473355]
# Error of the iteration 765: [ 0.00788305]
# Error of the iteration 766: [ 0.00416304]
# Error of the iteration 767: [ 0.04539499]
# Error of the iteration 768: [ 0.00454874]
# Error of the iteration 769: [ 0.00848775]
# Error of the iteration 770: [ 0.04383391]
# Error of the iteration 771: [ 0.00667967]
# Error of the iteration 772: [ 0.00441829]
# Error of the iteration 773: [ 0.00922293]
# Error of the iteration 774: [ 0.00799963]
# Error of the iteration 775: [ 0.00648751]
# Error of the iteration 776: [ 0.04562892]
# Error of the iteration 777: [ 0.04791415]
# Error of the iteration 778: [ 0.0481739]
# Error of the iteration 779: [ 0.00876903]
# Error of the iteration 780: [ 0.04702785]
# Error of the iteration 781: [ 0.09425016]
# Error of the iteration 782: [ 0.00758642]
# Error of the iteration 783: [ 0.07941251]
# Error of the iteration 784: [ 0.13660488]
# Error of the iteration 785: [ 0.14637336]
# Error of the iteration 786: [ 0.0559378]
# Error of the iteration 787: [ 0.08814657]
# Error of the iteration 788: [ 0.04844406]
# Error of the iteration 789: [ 0.05636179]
# Error of the iteration 790: [ 0.07248227]
# Error of the iteration 791: [ 0.0944657]
# Error of the iteration 792: [ 0.07316953]
# Error of the iteration 793: [ 0.0109613]
# Error of the iteration 794: [ 0.00541155]
# Error of the iteration 795: [ 0.04192262]
# Error of the iteration 796: [ 0.09000523]
# Error of the iteration 797: [ 0.00689685]
# Error of the iteration 798: [ 0.05152971]
# Error of the iteration 799: [ 0.0525731]
# Error of the iteration 800: [ 0.00516496]
# Error of the iteration 801: [ 0.00868057]
# Error of the iteration 802: [ 0.04768925]
# Error of the iteration 803: [ 0.00834831]
# Error of the iteration 804: [ 0.08507771]
# Error of the iteration 805: [ 0.05539494]
# Error of the iteration 806: [ 0.04542111]
# Error of the iteration 807: [ 0.16587634]
# Error of the iteration 808: [ 0.00793298]
# Error of the iteration 809: [ 0.06385498]
# Error of the iteration 810: [ 0.05015441]
# Error of the iteration 811: [ 0.00629057]
# Error of the iteration 812: [ 0.00653105]
# Error of the iteration 813: [ 0.00599872]
# Error of the iteration 814: [ 0.00498339]
# Error of the iteration 815: [ 0.05484382]
# Error of the iteration 816: [ 0.0464966]
# Error of the iteration 817: [ 0.05404402]
# Error of the iteration 818: [ 0.12457772]
# Error of the iteration 819: [ 0.00341182]
# Error of the iteration 820: [ 0.00740401]
# Error of the iteration 821: [ 0.00759743]
# Error of the iteration 822: [ 0.00962328]
# Error of the iteration 823: [ 0.06026014]
# Error of the iteration 824: [ 0.08496798]
# Error of the iteration 825: [ 0.00646649]
# Error of the iteration 826: [ 0.00504497]
# Error of the iteration 827: [ 0.04704699]
# Error of the iteration 828: [ 0.05424027]
# Error of the iteration 829: [ 0.10236797]
# Error of the iteration 830: [ 0.04626271]
# Error of the iteration 831: [ 0.00614719]
# Error of the iteration 832: [ 0.00998705]
# Error of the iteration 833: [ 0.00534601]
# Error of the iteration 834: [ 0.00635601]
# Error of the iteration 835: [ 0.01053785]
# Error of the iteration 836: [ 0.00609285]
# Error of the iteration 837: [ 0.08273465]
# Error of the iteration 838: [ 0.00792235]
# Error of the iteration 839: [ 0.07900324]
# Error of the iteration 840: [ 0.00704222]
# Error of the iteration 841: [ 0.00749965]
# Error of the iteration 842: [ 0.0068735]
# Error of the iteration 843: [ 0.0474027]
# Error of the iteration 844: [ 0.00809181]
# Error of the iteration 845: [ 0.10065454]
# Error of the iteration 846: [ 0.07968669]
# Error of the iteration 847: [ 0.00699858]
# Error of the iteration 848: [ 0.00715432]
# Error of the iteration 849: [ 0.00695167]
# Error of the iteration 850: [ 0.00672908]
# Error of the iteration 851: [ 0.0534925]
# Error of the iteration 852: [ 0.00753662]
# Error of the iteration 853: [ 0.05296105]
# Error of the iteration 854: [ 0.00852365]
# Error of the iteration 855: [ 0.00665533]
# Error of the iteration 856: [ 0.00342071]
# Error of the iteration 857: [ 0.00853941]
# Error of the iteration 858: [ 0.00507742]
# Error of the iteration 859: [ 0.04849034]
# Error of the iteration 860: [ 0.08994338]
# Error of the iteration 861: [ 0.04846827]
# Error of the iteration 862: [ 0.04813771]
# Error of the iteration 863: [ 0.04938489]
# Error of the iteration 864: [ 0.00413171]
# Error of the iteration 865: [ 0.04384381]
# Error of the iteration 866: [ 0.08198428]
# Error of the iteration 867: [ 0.0516124]
# Error of the iteration 868: [ 0.00637967]
# Error of the iteration 869: [ 0.04049179]
# Error of the iteration 870: [ 0.1378379]
# Error of the iteration 871: [ 0.0059785]
# Error of the iteration 872: [ 0.04960972]
# Error of the iteration 873: [ 0.0076832]
# Error of the iteration 874: [ 0.00652817]
# Error of the iteration 875: [ 0.09166856]
# Error of the iteration 876: [ 0.00681073]
# Error of the iteration 877: [ 0.07335519]
# Error of the iteration 878: [ 0.0795119]
# Error of the iteration 879: [ 0.08474814]
# Error of the iteration 880: [ 0.00928121]
# Error of the iteration 881: [ 0.00819025]
# Error of the iteration 882: [ 0.04705389]
# Error of the iteration 883: [ 0.00535376]
# Error of the iteration 884: [ 0.00499799]
# Error of the iteration 885: [ 0.00535849]
# Error of the iteration 886: [ 0.13192369]
# Error of the iteration 887: [ 0.00676651]
# Error of the iteration 888: [ 0.04883373]
# Error of the iteration 889: [ 0.00549812]
# Error of the iteration 890: [ 0.09133626]
# Error of the iteration 891: [ 0.00706566]
# Error of the iteration 892: [ 0.05431947]
# Error of the iteration 893: [ 0.0054032]
# Error of the iteration 894: [ 0.00924368]
# Error of the iteration 895: [ 0.05356472]
# Error of the iteration 896: [ 0.0075195]
# Error of the iteration 897: [ 0.05406139]
# Error of the iteration 898: [ 0.04782274]
# Error of the iteration 899: [ 0.01026212]
# Error of the iteration 900: [ 0.00794141]
# Error of the iteration 901: [ 0.08650904]
# Error of the iteration 902: [ 0.00431562]
# Error of the iteration 903: [ 0.04467988]
# Error of the iteration 904: [ 0.04701749]
# Error of the iteration 905: [ 0.00501257]
# Error of the iteration 906: [ 0.00614769]
# Error of the iteration 907: [ 0.06106497]
# Error of the iteration 908: [ 0.00791435]
# Error of the iteration 909: [ 0.06174008]
# Error of the iteration 910: [ 0.00808166]
# Error of the iteration 911: [ 0.03513268]
# Error of the iteration 912: [ 0.10258126]
# Error of the iteration 913: [ 0.0062338]
# Error of the iteration 914: [ 0.0738414]
# Error of the iteration 915: [ 0.04686197]
# Error of the iteration 916: [ 0.08013175]
# Error of the iteration 917: [ 0.00740367]
# Error of the iteration 918: [ 0.09774232]
# Error of the iteration 919: [ 0.00630287]
# Error of the iteration 920: [ 0.00838475]
# Error of the iteration 921: [ 0.11525549]
# Error of the iteration 922: [ 0.08081843]
# Error of the iteration 923: [ 0.00902494]
# Error of the iteration 924: [ 0.08684282]
# Error of the iteration 925: [ 0.10444953]
# Error of the iteration 926: [ 0.04714152]
# Error of the iteration 927: [ 0.08470054]
# Error of the iteration 928: [ 0.09052265]
# Error of the iteration 929: [ 0.04350162]
# Error of the iteration 930: [ 0.00975517]
# Error of the iteration 931: [ 0.00717999]
# Error of the iteration 932: [ 0.04320393]
# Error of the iteration 933: [ 0.00778833]
# Error of the iteration 934: [ 0.07773145]
# Error of the iteration 935: [ 0.04811465]
# Error of the iteration 936: [ 0.05149755]
# Error of the iteration 937: [ 0.01201609]
# Error of the iteration 938: [ 0.0076461]
# Error of the iteration 939: [ 0.01049971]
# Error of the iteration 940: [ 0.00679968]
# Error of the iteration 941: [ 0.00699157]
# Error of the iteration 942: [ 0.16062014]
# Error of the iteration 943: [ 0.05016076]
# Error of the iteration 944: [ 0.00760993]
# Error of the iteration 945: [ 0.00709458]
# Error of the iteration 946: [ 0.00462333]
# Error of the iteration 947: [ 0.00374498]
# Error of the iteration 948: [ 0.00884502]
# Error of the iteration 949: [ 0.0070729]
# Error of the iteration 950: [ 0.00648177]
# Error of the iteration 951: [ 0.04939059]
# Error of the iteration 952: [ 0.00478102]
# Error of the iteration 953: [ 0.00590571]
# Error of the iteration 954: [ 0.04397112]
# Error of the iteration 955: [ 0.00974922]
# Error of the iteration 956: [ 0.12658588]
# Error of the iteration 957: [ 0.00498329]
# Error of the iteration 958: [ 0.00668699]
# Error of the iteration 959: [ 0.0422873]
# Error of the iteration 960: [ 0.09195811]
# Error of the iteration 961: [ 0.00413289]
# Error of the iteration 962: [ 0.08336087]
# Error of the iteration 963: [ 0.11441549]
# Error of the iteration 964: [ 0.00503811]
# Error of the iteration 965: [ 0.05098662]
# Error of the iteration 966: [ 0.00463726]
# Error of the iteration 967: [ 0.05101929]
# Error of the iteration 968: [ 0.04121786]
# Error of the iteration 969: [ 0.00690995]
# Error of the iteration 970: [ 0.09859955]
# Error of the iteration 971: [ 0.09094706]
# Error of the iteration 972: [ 0.00671377]
# Error of the iteration 973: [ 0.00667804]
# Error of the iteration 974: [ 0.08795277]
# Error of the iteration 975: [ 0.00784163]
# Error of the iteration 976: [ 0.00713128]
# Error of the iteration 977: [ 0.00734117]
# Error of the iteration 978: [ 0.0501471]
# Error of the iteration 979: [ 0.13443117]
# Error of the iteration 980: [ 0.05149232]
# Error of the iteration 981: [ 0.00835677]
# Error of the iteration 982: [ 0.00678619]
# Error of the iteration 983: [ 0.05779664]
# Error of the iteration 984: [ 0.05289075]
# Error of the iteration 985: [ 0.05131664]
# Error of the iteration 986: [ 0.05013634]
# Error of the iteration 987: [ 0.06095948]
# Error of the iteration 988: [ 0.04878336]
# Error of the iteration 989: [ 0.04894687]
# Error of the iteration 990: [ 0.0067816]
# Error of the iteration 991: [ 0.00656943]
# Error of the iteration 992: [ 0.00727203]
# Error of the iteration 993: [ 0.00527474]
# Error of the iteration 994: [ 0.00449326]
# Error of the iteration 995: [ 0.0071846]
# Error of the iteration 996: [ 0.00847475]
# Error of the iteration 997: [ 0.07550987]
# Error of the iteration 998: [ 0.09433107]
# Error of the iteration 999: [ 0.00659131]
# Error of the iteration 1000: [ 0.04249975]
# Error of the iteration 1001: [ 0.0449881]
# Error of the iteration 1002: [ 0.00692143]
# Error of the iteration 1003: [ 0.00739811]
# Error of the iteration 1004: [ 0.00774285]
# Error of the iteration 1005: [ 0.09318705]
# Error of the iteration 1006: [ 0.00618929]
# Error of the iteration 1007: [ 0.07739431]
# Error of the iteration 1008: [ 0.00646972]
# Error of the iteration 1009: [ 0.00387274]
# Error of the iteration 1010: [ 0.0474222]
# Error of the iteration 1011: [ 0.00733188]
# Error of the iteration 1012: [ 0.04095405]
# Error of the iteration 1013: [ 0.0054296]
# Error of the iteration 1014: [ 0.00735336]
# Error of the iteration 1015: [ 0.05077724]
# Error of the iteration 1016: [ 0.05426808]
# Error of the iteration 1017: [ 0.00617386]
# Error of the iteration 1018: [ 0.00755295]
# Error of the iteration 1019: [ 0.00694835]
# Error of the iteration 1020: [ 0.07586454]
# Error of the iteration 1021: [ 0.04628016]
# Error of the iteration 1022: [ 0.08387772]
# Error of the iteration 1023: [ 0.04830801]
# Error of the iteration 1024: [ 0.04796629]
# Error of the iteration 1025: [ 0.01398175]
# Error of the iteration 1026: [ 0.05060994]
# Error of the iteration 1027: [ 0.00649031]
# Error of the iteration 1028: [ 0.0785919]
# Error of the iteration 1029: [ 0.04802827]
# Error of the iteration 1030: [ 0.09355352]
# Error of the iteration 1031: [ 0.00743693]
# Error of the iteration 1032: [ 0.21564535]
# Error of the iteration 1033: [ 0.05310922]
# Error of the iteration 1034: [ 0.00677893]
# Error of the iteration 1035: [ 0.04843575]
# Error of the iteration 1036: [ 0.01053878]
# Error of the iteration 1037: [ 0.01108755]
# Error of the iteration 1038: [ 0.00780317]
# Error of the iteration 1039: [ 0.0481163]
# Error of the iteration 1040: [ 0.12022695]
# Error of the iteration 1041: [ 0.00566258]
# Error of the iteration 1042: [ 0.00964836]
# Error of the iteration 1043: [ 0.04613816]
# Error of the iteration 1044: [ 0.00529412]
# Error of the iteration 1045: [ 0.00865785]
# Error of the iteration 1046: [ 0.10564875]
# Error of the iteration 1047: [ 0.05655022]
# Error of the iteration 1048: [ 0.04094718]
# Error of the iteration 1049: [ 0.05626618]
# Error of the iteration 1050: [ 0.00872363]
# Error of the iteration 1051: [ 0.00692473]
# Error of the iteration 1052: [ 0.04077893]
# Error of the iteration 1053: [ 0.04314846]
# Error of the iteration 1054: [ 0.0089803]
# Error of the iteration 1055: [ 0.0531839]
# Error of the iteration 1056: [ 0.05437722]
# Error of the iteration 1057: [ 0.00753643]
# Error of the iteration 1058: [ 0.05969938]
# Error of the iteration 1059: [ 0.05221373]
# Error of the iteration 1060: [ 0.03974289]
# Error of the iteration 1061: [ 0.00875177]
# Error of the iteration 1062: [ 0.05530623]
# Error of the iteration 1063: [ 0.04209123]
# Error of the iteration 1064: [ 0.04765534]
# Error of the iteration 1065: [ 0.00609216]
# Error of the iteration 1066: [ 0.0492837]
# Error of the iteration 1067: [ 0.04908464]
# Error of the iteration 1068: [ 0.04428128]
# Error of the iteration 1069: [ 0.05683982]
# Error of the iteration 1070: [ 0.14631778]
# Error of the iteration 1071: [ 0.08812273]
# Error of the iteration 1072: [ 0.08498206]
# Error of the iteration 1073: [ 0.13341717]
# Error of the iteration 1074: [ 0.0507533]
# Error of the iteration 1075: [ 0.0428001]
# Error of the iteration 1076: [ 0.00735194]
# Error of the iteration 1077: [ 0.07856494]
# Error of the iteration 1078: [ 0.00784133]
# Error of the iteration 1079: [ 0.08898499]
# Error of the iteration 1080: [ 0.05073847]
# Error of the iteration 1081: [ 0.05061449]
# Error of the iteration 1082: [ 0.05304397]
# Error of the iteration 1083: [ 0.09281322]
# Error of the iteration 1084: [ 0.00764934]
# Error of the iteration 1085: [ 0.04058079]
# Error of the iteration 1086: [ 0.0067298]
# Error of the iteration 1087: [ 0.00756595]
# Error of the iteration 1088: [ 0.05800642]
# Error of the iteration 1089: [ 0.00407322]
# Error of the iteration 1090: [ 0.00545647]
# Error of the iteration 1091: [ 0.09363142]
# Error of the iteration 1092: [ 0.08239034]
# Error of the iteration 1093: [ 0.05178476]
# Error of the iteration 1094: [ 0.05313261]
# Error of the iteration 1095: [ 0.04625308]
# Error of the iteration 1096: [ 0.00910059]
# Error of the iteration 1097: [ 0.11003368]
# Error of the iteration 1098: [ 0.04909661]
# Error of the iteration 1099: [ 0.00609916]
# Error of the iteration 1100: [ 0.05113362]
# Error of the iteration 1101: [ 0.05485474]
# Error of the iteration 1102: [ 0.08189433]
# Error of the iteration 1103: [ 0.00504612]
# Error of the iteration 1104: [ 0.08786471]
# Error of the iteration 1105: [ 0.00601753]
# Error of the iteration 1106: [ 0.09550857]
# Error of the iteration 1107: [ 0.04979025]
# Error of the iteration 1108: [ 0.00845211]
# Error of the iteration 1109: [ 0.05398437]
# Error of the iteration 1110: [ 0.05459734]
# Error of the iteration 1111: [ 0.00844884]
# Error of the iteration 1112: [ 0.06116656]
# Error of the iteration 1113: [ 0.03860235]
# Error of the iteration 1114: [ 0.07879068]
# Error of the iteration 1115: [ 0.00493877]
# Error of the iteration 1116: [ 0.0063094]
# Error of the iteration 1117: [ 0.0312218]
# Error of the iteration 1118: [ 0.0524091]
# Error of the iteration 1119: [ 0.03865406]
# Error of the iteration 1120: [ 0.04980345]
# Error of the iteration 1121: [ 0.00749139]
# Error of the iteration 1122: [ 0.0912979]
# Error of the iteration 1123: [ 0.00860502]
# Error of the iteration 1124: [ 0.03242204]
# Error of the iteration 1125: [ 0.05875423]
# Error of the iteration 1126: [ 0.00537331]
# Error of the iteration 1127: [ 0.00652085]
# Error of the iteration 1128: [ 0.00763412]
# Error of the iteration 1129: [ 0.1026803]
# Error of the iteration 1130: [ 0.07968088]
# Error of the iteration 1131: [ 0.03860321]
# Error of the iteration 1132: [ 0.00467342]
# Error of the iteration 1133: [ 0.0644026]
# Error of the iteration 1134: [ 0.09528282]
# Error of the iteration 1135: [ 0.00607706]
# Error of the iteration 1136: [ 0.11373733]
# Error of the iteration 1137: [ 0.13729726]
# Error of the iteration 1138: [ 0.00694988]
# Error of the iteration 1139: [ 0.00622918]
# Error of the iteration 1140: [ 0.0486714]
# Error of the iteration 1141: [ 0.04183283]
# Error of the iteration 1142: [ 0.05286645]
# Error of the iteration 1143: [ 0.00676265]
# Error of the iteration 1144: [ 0.0068667]
# ...
# Error of the iteration 15001: [ 0.00038962]
# Error of the iteration 15002: [ 0.00021808]
# Error of the iteration 15003: [ 0.00022281]
# Error of the iteration 15004: [ 0.00111267]
# Error of the iteration 15005: [ 0.05042671]
# Error of the iteration 15006: [ 0.02176623]
# Error of the iteration 15007: [ 0.00019216]
# Error of the iteration 15008: [ 0.03592609]
# Error of the iteration 15009: [ 0.00211542]
# Error of the iteration 15010: [ 0.00017792]
# Error of the iteration 15011: [ 0.00017747]
# Error of the iteration 15012: [ 0.00124963]
# Error of the iteration 15013: [  8.06310377e-05]
# Error of the iteration 15014: [ 0.00031881]
# Error of the iteration 15015: [ 0.02701382]
# Error of the iteration 15016: [  9.70290244e-05]
# Error of the iteration 15017: [  9.06872032e-05]
# Error of the iteration 15018: [ 0.00037875]
# Error of the iteration 15019: [ 0.06188521]
# Error of the iteration 15020: [ 0.04723891]
# Error of the iteration 15021: [ 0.0018679]
# Error of the iteration 15022: [ 0.0001877]
# Error of the iteration 15023: [ 0.03960863]
# Error of the iteration 15024: [ 0.0016173]
# Error of the iteration 15025: [ 0.06042678]
# Error of the iteration 15026: [ 0.04443077]
# Error of the iteration 15027: [ 0.04236053]
# Error of the iteration 15028: [ 0.02551129]
# Error of the iteration 15029: [ 0.04160432]
# Error of the iteration 15030: [ 0.05554368]
# Error of the iteration 15031: [ 0.04250827]
# Error of the iteration 15032: [ 0.05319155]
# Error of the iteration 15033: [ 0.0867767]
# Error of the iteration 15034: [ 0.06876552]
# Error of the iteration 15035: [ 0.05983941]
# Error of the iteration 15036: [ 0.10244737]
# Error of the iteration 15037: [ 0.11358546]
# Error of the iteration 15038: [ 0.0489499]
# Error of the iteration 15039: [  7.90537718e-05]
# Error of the iteration 15040: [ 0.00023016]
# Error of the iteration 15041: [ 0.05470658]
# Error of the iteration 15042: [ 0.00032958]
# Error of the iteration 15043: [ 0.03949948]
# Error of the iteration 15044: [ 0.0003531]
# Error of the iteration 15045: [ 0.0091615]
# Error of the iteration 15046: [ 0.0487229]
# Error of the iteration 15047: [ 0.0576895]
# Error of the iteration 15048: [ 0.00064002]
# Error of the iteration 15049: [ 0.05712577]
# Error of the iteration 15050: [ 0.06073123]
# Error of the iteration 15051: [ 0.04799285]
# Error of the iteration 15052: [  7.41553329e-05]
# Error of the iteration 15053: [ 0.04814506]
# Error of the iteration 15054: [ 0.02612702]
# Error of the iteration 15055: [ 0.04830216]
# Error of the iteration 15056: [ 0.0002063]
# Error of the iteration 15057: [ 0.00032397]
# Error of the iteration 15058: [ 0.00380174]
# Error of the iteration 15059: [ 0.05972074]
# Error of the iteration 15060: [ 0.02362843]
# Error of the iteration 15061: [ 0.12006341]
# Error of the iteration 15062: [ 0.10145244]
# Error of the iteration 15063: [  6.55348094e-05]
# Error of the iteration 15064: [ 0.00492998]
# Error of the iteration 15065: [ 0.00033407]
# Error of the iteration 15066: [ 0.0004125]
# Error of the iteration 15067: [ 0.1583087]
# Error of the iteration 15068: [ 0.05967264]
# Error of the iteration 15069: [ 0.00031609]
# Error of the iteration 15070: [ 0.04548034]
# Error of the iteration 15071: [ 0.19518342]
# Error of the iteration 15072: [ 0.06116379]
# Error of the iteration 15073: [ 0.00016663]
# Error of the iteration 15074: [ 0.00767426]
# Error of the iteration 15075: [ 0.11265588]
# Error of the iteration 15076: [ 0.00035469]
# Error of the iteration 15077: [ 0.00050144]
# Error of the iteration 15078: [ 0.04086064]
# Error of the iteration 15079: [ 0.0009835]
# Error of the iteration 15080: [ 0.00108282]
# Error of the iteration 15081: [  7.00415916e-05]
# Error of the iteration 15082: [ 0.00012499]
# Error of the iteration 15083: [ 0.15214824]
# Error of the iteration 15084: [ 0.06898311]
# Error of the iteration 15085: [ 0.05400326]
# Error of the iteration 15086: [ 0.0209446]
# Error of the iteration 15087: [ 0.03262985]
# Error of the iteration 15088: [  8.25397125e-05]
# Error of the iteration 15089: [ 0.10711537]
# Error of the iteration 15090: [ 0.00024983]
# Error of the iteration 15091: [ 0.00119165]
# Error of the iteration 15092: [ 0.05681467]
# Error of the iteration 15093: [  9.39344628e-05]
# Error of the iteration 15094: [ 0.06749633]
# Error of the iteration 15095: [ 0.0017115]
# Error of the iteration 15096: [ 0.06172733]
# Error of the iteration 15097: [ 0.00027561]
# Error of the iteration 15098: [ 0.05394045]
# Error of the iteration 15099: [ 0.05425958]
# Error of the iteration 15100: [ 0.02441398]
# Error of the iteration 15101: [ 0.00049663]
# Error of the iteration 15102: [ 0.00021104]
# Error of the iteration 15103: [ 0.0154504]
# Error of the iteration 15104: [  5.27506583e-05]
# Error of the iteration 15105: [ 0.00254164]
# Error of the iteration 15106: [ 0.04385388]
# Error of the iteration 15107: [ 0.00011475]
# Error of the iteration 15108: [ 0.00023713]
# Error of the iteration 15109: [ 0.00040445]
# Error of the iteration 15110: [ 0.00071148]
# Error of the iteration 15111: [ 0.00015145]
# Error of the iteration 15112: [ 0.04539805]
# Error of the iteration 15113: [ 0.05768437]
# Error of the iteration 15114: [ 0.05020268]
# Error of the iteration 15115: [ 0.00064475]
# Error of the iteration 15116: [ 0.04251694]
# Error of the iteration 15117: [ 0.11690051]
# Error of the iteration 15118: [ 0.00050448]
# Error of the iteration 15119: [ 0.05649891]
# Error of the iteration 15120: [ 0.16382272]
# Error of the iteration 15121: [ 0.13688103]
# Error of the iteration 15122: [ 0.05867386]
# Error of the iteration 15123: [ 0.10472364]
# Error of the iteration 15124: [ 0.05465913]
# Error of the iteration 15125: [ 0.06597218]
# Error of the iteration 15126: [ 0.05393781]
# Error of the iteration 15127: [ 0.11425043]
# Error of the iteration 15128: [ 0.03212559]
# Error of the iteration 15129: [ 0.00198334]
# Error of the iteration 15130: [ 0.0001553]
# Error of the iteration 15131: [ 0.04010408]
# Error of the iteration 15132: [ 0.10543834]
# Error of the iteration 15133: [ 0.00050831]
# Error of the iteration 15134: [ 0.05705827]
# Error of the iteration 15135: [ 0.0543326]
# Error of the iteration 15136: [ 0.00199563]
# Error of the iteration 15137: [ 0.0030185]
# Error of the iteration 15138: [ 0.05579875]
# Error of the iteration 15139: [ 0.0002948]
# Error of the iteration 15140: [ 0.05889761]
# Error of the iteration 15141: [ 0.04008127]
# Error of the iteration 15142: [ 0.03189889]
# Error of the iteration 15143: [ 0.16415815]
# Error of the iteration 15144: [ 0.0001542]
# Error of the iteration 15145: [ 0.01604461]
# Error of the iteration 15146: [ 0.05904292]
# Error of the iteration 15147: [ 0.00111743]
# Error of the iteration 15148: [  7.71562605e-05]
# Error of the iteration 15149: [ 0.00022616]
# Error of the iteration 15150: [  8.20322312e-05]
# Error of the iteration 15151: [ 0.05664596]
# Error of the iteration 15152: [ 0.05078058]
# Error of the iteration 15153: [ 0.06698763]
# Error of the iteration 15154: [ 0.10941554]
# Error of the iteration 15155: [  6.52389502e-05]
# Error of the iteration 15156: [ 0.00083389]
# Error of the iteration 15157: [ 0.00030083]
# Error of the iteration 15158: [  6.99439683e-05]
# Error of the iteration 15159: [ 0.066807]
# Error of the iteration 15160: [ 0.07815066]
# Error of the iteration 15161: [ 0.00225741]
# Error of the iteration 15162: [  3.82821400e-05]
# Error of the iteration 15163: [ 0.05526849]
# Error of the iteration 15164: [ 0.04422878]
# Error of the iteration 15165: [ 0.11027293]
# Error of the iteration 15166: [ 0.04369719]
# Error of the iteration 15167: [  8.07376777e-05]
# Error of the iteration 15168: [ 0.00483122]
# Error of the iteration 15169: [  9.64440399e-05]
# Error of the iteration 15170: [ 0.00087736]
# Error of the iteration 15171: [ 0.00979461]
# Error of the iteration 15172: [ 0.00044002]
# Error of the iteration 15173: [ 0.05213641]
# Error of the iteration 15174: [ 0.00024919]
# Error of the iteration 15175: [ 0.05508241]
# Error of the iteration 15176: [ 0.00305186]
# Error of the iteration 15177: [ 0.00078306]
# Error of the iteration 15178: [ 0.00037975]
# Error of the iteration 15179: [ 0.04688876]
# Error of the iteration 15180: [ 0.00103754]
# Error of the iteration 15181: [ 0.12293654]
# Error of the iteration 15182: [ 0.0679836]
# Error of the iteration 15183: [ 0.00085695]
# Error of the iteration 15184: [ 0.00170501]
# Error of the iteration 15185: [ 0.0008257]
# Error of the iteration 15186: [  5.47125379e-05]
# Error of the iteration 15187: [ 0.05611174]
# Error of the iteration 15188: [ 0.00142741]
# Error of the iteration 15189: [ 0.05616354]
# Error of the iteration 15190: [  9.93778154e-05]
# Error of the iteration 15191: [ 0.00014402]
# Error of the iteration 15192: [  5.39881910e-05]
# Error of the iteration 15193: [ 0.0048778]
# Error of the iteration 15194: [ 0.00026439]
# Error of the iteration 15195: [ 0.04621304]
# Error of the iteration 15196: [ 0.07147021]
# Error of the iteration 15197: [ 0.05457311]
# Error of the iteration 15198: [ 0.05723749]
# Error of the iteration 15199: [ 0.05152723]
# Error of the iteration 15200: [  9.54685604e-05]
# Error of the iteration 15201: [ 0.03944188]
# Error of the iteration 15202: [ 0.07644695]
# Error of the iteration 15203: [ 0.04113527]
# Error of the iteration 15204: [ 0.00018885]
# Error of the iteration 15205: [ 0.00943698]
# Error of the iteration 15206: [ 0.10016709]
# Error of the iteration 15207: [ 0.00010361]
# Error of the iteration 15208: [ 0.04951203]
# Error of the iteration 15209: [ 0.00089377]
# Error of the iteration 15210: [ 0.00096819]
# Error of the iteration 15211: [ 0.09205988]
# Error of the iteration 15212: [ 0.00030485]
# Error of the iteration 15213: [ 0.01982893]
# Error of the iteration 15214: [ 0.0761235]
# Error of the iteration 15215: [ 0.0695072]
# Error of the iteration 15216: [ 0.00191968]
# Error of the iteration 15217: [ 0.00189233]
# Error of the iteration 15218: [ 0.05262994]
# Error of the iteration 15219: [ 0.00078347]
# Error of the iteration 15220: [  7.05608287e-05]
# Error of the iteration 15221: [  7.89305367e-05]
# Error of the iteration 15222: [ 0.15936768]
# Error of the iteration 15223: [ 0.00073097]
# Error of the iteration 15224: [ 0.05279639]
# Error of the iteration 15225: [  3.97764520e-05]
# Error of the iteration 15226: [ 0.0868714]
# Error of the iteration 15227: [ 0.00341545]
# Error of the iteration 15228: [ 0.05366837]
# Error of the iteration 15229: [ 0.00015056]
# Error of the iteration 15230: [ 0.00322163]
# Error of the iteration 15231: [ 0.05767327]
# Error of the iteration 15232: [ 0.00022986]
# Error of the iteration 15233: [ 0.03309313]
# Error of the iteration 15234: [ 0.06031751]
# Error of the iteration 15235: [ 0.00087384]
# Error of the iteration 15236: [ 0.00201306]
# Error of the iteration 15237: [ 0.10381706]
# Error of the iteration 15238: [  3.53453645e-05]
# Error of the iteration 15239: [ 0.04058932]
# Error of the iteration 15240: [ 0.0500192]
# Error of the iteration 15241: [  7.14766515e-05]
# Error of the iteration 15242: [ 0.00161234]
# Error of the iteration 15243: [ 0.06615323]
# Error of the iteration 15244: [ 0.00022018]
# Error of the iteration 15245: [ 0.06902458]
# Error of the iteration 15246: [ 0.0018336]
# Error of the iteration 15247: [ 0.00254938]
# Error of the iteration 15248: [ 0.1211367]
# Error of the iteration 15249: [ 0.0005726]
# Error of the iteration 15250: [ 0.05784719]
# Error of the iteration 15251: [ 0.04454178]
# Error of the iteration 15252: [ 0.06091098]
# Error of the iteration 15253: [ 0.00067118]
# Error of the iteration 15254: [ 0.10857568]
# Error of the iteration 15255: [ 0.00029411]
# Error of the iteration 15256: [ 0.00027018]
# Error of the iteration 15257: [ 0.09465672]
# Error of the iteration 15258: [ 0.06186396]
# Error of the iteration 15259: [ 0.00269311]
# Error of the iteration 15260: [ 0.07815375]
# Error of the iteration 15261: [ 0.12292788]
# Error of the iteration 15262: [ 0.05499405]
# Error of the iteration 15263: [ 0.07929305]
# Error of the iteration 15264: [ 0.11205293]
# Error of the iteration 15265: [ 0.02356074]
# Error of the iteration 15266: [ 0.00040836]
# Error of the iteration 15267: [ 0.00015545]
# Error of the iteration 15268: [ 0.00998694]
# Error of the iteration 15269: [ 0.00025611]
# Error of the iteration 15270: [ 0.07848441]
# Error of the iteration 15271: [ 0.05916655]
# Error of the iteration 15272: [ 0.05886868]
# Error of the iteration 15273: [ 0.00227244]
# Error of the iteration 15274: [ 0.00047714]
# Error of the iteration 15275: [ 0.00166442]
# Error of the iteration 15276: [ 0.00069683]
# Error of the iteration 15277: [ 0.00063598]
# Error of the iteration 15278: [ 0.19090979]
# Error of the iteration 15279: [ 0.03517473]
# Error of the iteration 15280: [ 0.00189397]
# Error of the iteration 15281: [ 0.0003208]
# Error of the iteration 15282: [ 0.00014777]
# Error of the iteration 15283: [  5.93097947e-05]
# Error of the iteration 15284: [ 0.00104137]
# Error of the iteration 15285: [ 0.00179549]
# Error of the iteration 15286: [ 0.00020172]
# Error of the iteration 15287: [ 0.05559749]
# Error of the iteration 15288: [  3.73423113e-05]
# Error of the iteration 15289: [ 0.00033853]
# Error of the iteration 15290: [ 0.03526591]
# Error of the iteration 15291: [ 0.00090468]
# Error of the iteration 15292: [ 0.14410631]
# Error of the iteration 15293: [  9.24140871e-05]
# Error of the iteration 15294: [  8.39107186e-05]
# Error of the iteration 15295: [ 0.05231467]
# Error of the iteration 15296: [ 0.10516609]
# Error of the iteration 15297: [ 0.00015453]
# Error of the iteration 15298: [ 0.08348855]
# Error of the iteration 15299: [ 0.09531989]
# Error of the iteration 15300: [ 0.00013694]
# Error of the iteration 15301: [ 0.05547769]
# Error of the iteration 15302: [ 0.00084211]
# Error of the iteration 15303: [ 0.04275194]
# Error of the iteration 15304: [ 0.02118137]
# Error of the iteration 15305: [ 0.00312254]
# Error of the iteration 15306: [ 0.10304872]
# Error of the iteration 15307: [ 0.09128275]
# Error of the iteration 15308: [ 0.00030448]
# Error of the iteration 15309: [ 0.00042141]
# Error of the iteration 15310: [ 0.09561977]
# Error of the iteration 15311: [ 0.00085185]
# Error of the iteration 15312: [ 0.00060939]
# Error of the iteration 15313: [ 0.00099865]
# Error of the iteration 15314: [ 0.05885548]
# Error of the iteration 15315: [ 0.12640287]
# Error of the iteration 15316: [ 0.04671036]
# Error of the iteration 15317: [ 0.00025454]
# Error of the iteration 15318: [ 0.0010059]
# Error of the iteration 15319: [ 0.06237845]
# Error of the iteration 15320: [ 0.06328164]
# Error of the iteration 15321: [ 0.05996374]
# Error of the iteration 15322: [ 0.04869243]
# Error of the iteration 15323: [ 0.06651537]
# Error of the iteration 15324: [ 0.04888874]
# Error of the iteration 15325: [ 0.03484378]
# Error of the iteration 15326: [ 0.00046894]
# Error of the iteration 15327: [ 0.00152499]
# Error of the iteration 15328: [ 0.00063922]
# Error of the iteration 15329: [ 0.00065904]
# Error of the iteration 15330: [  6.05979001e-05]
# Error of the iteration 15331: [ 0.00450922]
# Error of the iteration 15332: [ 0.0002534]
# Error of the iteration 15333: [ 0.07228905]
# Error of the iteration 15334: [ 0.1129027]
# Error of the iteration 15335: [ 0.00190966]
# Error of the iteration 15336: [ 0.02063061]
# Error of the iteration 15337: [ 0.04790819]
# Error of the iteration 15338: [ 0.00022712]
# Error of the iteration 15339: [ 0.00119849]
# Error of the iteration 15340: [ 0.00030758]
# Error of the iteration 15341: [ 0.1195892]
# Error of the iteration 15342: [ 0.0003358]
# Error of the iteration 15343: [ 0.05480137]
# Error of the iteration 15344: [ 0.00022957]
# Error of the iteration 15345: [  9.51188497e-05]
# Error of the iteration 15346: [ 0.05700576]
# Error of the iteration 15347: [ 0.0002466]
# Error of the iteration 15348: [ 0.04504591]
# Error of the iteration 15349: [ 0.00115607]
# Error of the iteration 15350: [ 0.00054957]
# Error of the iteration 15351: [ 0.03980317]
# Error of the iteration 15352: [ 0.06237704]
# Error of the iteration 15353: [ 0.00046218]
# Error of the iteration 15354: [ 0.00418211]
# Error of the iteration 15355: [ 0.00054333]
# Error of the iteration 15356: [ 0.05753453]
# Error of the iteration 15357: [ 0.04467558]
# Error of the iteration 15358: [ 0.10543888]
# Error of the iteration 15359: [ 0.05815356]
# Error of the iteration 15360: [ 0.0479348]
# Accuracy of our LLSR:90.2%
